# %% [markdown]
# # inmemorycache 테스트

# %%
#기존 캐시된 키 강제 제거
if 'OPENAI_API_KEY' in os.environ:
    del os.environ['OPENAI_API_KEY']

# %%
from dotenv import load_dotenv
import os

load_dotenv()

OPENAI_API_KEY = os.environ['OPENAI_API_KEY']
#PINECONE_API_KEY = os.environ['PINECONE_API_KEY']

print("API 키 로드 완료")
print(f"OpenAI Key: {OPENAI_API_KEY[:10]}...")
# Out:
# API 키 로드 완료
# OpenAI Key: sk-proj-00...

# %%
from langchain_core.globals import set_llm_cache
from langchain_core.caches import InMemoryCache
from langchain_core.messages import HumanMessage
from langchain_openai import ChatOpenAI

# %%
from dotenv import load_dotenv
load_dotenv()

from langchain_core.globals import set_llm_cache
from langchain_core.caches import InMemoryCache
from langchain_core.messages import HumanMessage
from langchain_openai import ChatOpenAI

set_llm_cache(InMemoryCache())
llm = ChatOpenAI(model="gpt-4o-mini")

# %%
message = [HumanMessage(content="서울 광장시장에서 가장 맛있는 길거리 음식은?")]

# %%
# 첫 번째 호출 - API 실제 호출, set_llm_cache사용
response = llm.invoke(message)
print(response.content)
# Out:
# 서울 광장시장에서 가장 인기 있는 길거리 음식으로는 여러 가지가 있지만, 그 중에서도 특히 유명한 몇 가지를 소개해드릴게요.
#
# 1. **떡볶이**: 매콤하고 쫄깃한 떡볶이는 광장시장에서 꼭 한 번 맛봐야 할 음식입니다. 다양한 소스와 함께 제공되기도 하며, 오뎅이나 계란과 함께 먹는 경우도 많습니다.
#
# 2. **순대**: 부드러운 순대는 각종 양념과 함께 제공되며, 특히 간장이나 고추장이 어우러진 맛이 일품입니다.
#
# 3. **튀김**: 다양한 해산물이나 채소를 튀긴 음식으로, 바삭한 식감이 즐겁습니다. 주로 간장 소스나 초장과 함께 제공됩니다.
#
# 4. **호떡**: 달콤한 설탕 시럽과 견과류가 들어간 호떡은 간식으로 인기가 많습니다. 따뜻하게 구워서 먹는 것이 포인트입니다.
#
# 5. **계란빵**: 따뜻한 빵 속에 계란이 들어있는 계란빵은 고소하고 부드러운 맛을 자랑합니다.
#
# 광장시장은 다양한 음식이 모여 있어 많은 선택지가 있으니, 여러 가지 길거리 음식을 시도해보는 것도 좋은 경험이 될 것입니다!

# %%
# 첫 번째 호출 - API 실제 호출, cache에 결과 저장
response = llm.invoke(message)
print(response.content)
# Out:
# 서울 광장시장에서 가장 인기 있는 길거리 음식으로는 여러 가지가 있지만, 그 중에서도 특히 유명한 몇 가지를 소개해드릴게요.
#
# 1. **떡볶이**: 매콤하고 쫄깃한 떡볶이는 광장시장에서 꼭 한 번 맛봐야 할 음식입니다. 다양한 소스와 함께 제공되기도 하며, 오뎅이나 계란과 함께 먹는 경우도 많습니다.
#
# 2. **순대**: 부드러운 순대는 각종 양념과 함께 제공되며, 특히 간장이나 고추장이 어우러진 맛이 일품입니다.
#
# 3. **튀김**: 다양한 해산물이나 채소를 튀긴 음식으로, 바삭한 식감이 즐겁습니다. 주로 간장 소스나 초장과 함께 제공됩니다.
#
# 4. **호떡**: 달콤한 설탕 시럽과 견과류가 들어간 호떡은 간식으로 인기가 많습니다. 따뜻하게 구워서 먹는 것이 포인트입니다.
#
# 5. **계란빵**: 따뜻한 빵 속에 계란이 들어있는 계란빵은 고소하고 부드러운 맛을 자랑합니다.
#
# 광장시장은 다양한 음식이 모여 있어 많은 선택지가 있으니, 여러 가지 길거리 음식을 시도해보는 것도 좋은 경험이 될 것입니다!

# %% [markdown]
# # SQLiteCache(database_path=".langchain.db")

# %%
from langchain_community.cache import SQLiteCache

set_llm_cache(SQLiteCache(database_path=".langchain.db"))
llm = ChatOpenAI(model="gpt-4o-mini")

message = [HumanMessage(content="서울 광장시장에서 가장 맛있는 길거리 음식은?")]

# %%
message = [HumanMessage(content="서울 광장시장에서 가장 맛있는 거리 음식은?")]

# %%
response = llm.invoke(message)
print(response.content)
# Out:
# 서울 광장시장에서 유명한 거리 음식에는 다양한 종류가 있습니다. 그 중에서도 특히 인기 있는 몇 가지를 소개하자면:
#
# 1. **떡볶이**: 매콤한 소스에 쌀떡과 채소가 어우러진 떡볶이는 많은 사람들에게 사랑받고 있습니다.
# 2. **오뎅**: 국물과 함께 제공되는 오뎅은 간편하게 먹을 수 있는 간식입니다.
# 3. **순대**: 한국식 소시지인 순대는 다양한 재료와 함께 맛볼 수 있으며, 특유의 맛이 매력적입니다.
# 4. **튀김**: 새우튀김이나 고구마튀김 등 다양한 튀김 요리가 있어 바삭한 식감을 즐길 수 있습니다.
# 5. **호떡**: 달콤한 채소나 견과류가 들어간 호떡은 특히 겨울철에 인기 있는 간식입니다.
#
# 이 외에도 많은 다양한 거리 음식이 있으니, 방문해보시면 여러 가지를 맛볼 수 있습니다!

# %%
response = llm.invoke(message)
print(response.content)
# Out:
# 서울 광장시장에서 유명한 거리 음식에는 다양한 종류가 있습니다. 그 중에서도 특히 인기 있는 몇 가지를 소개하자면:
#
# 1. **떡볶이**: 매콤한 소스에 쌀떡과 채소가 어우러진 떡볶이는 많은 사람들에게 사랑받고 있습니다.
# 2. **오뎅**: 국물과 함께 제공되는 오뎅은 간편하게 먹을 수 있는 간식입니다.
# 3. **순대**: 한국식 소시지인 순대는 다양한 재료와 함께 맛볼 수 있으며, 특유의 맛이 매력적입니다.
# 4. **튀김**: 새우튀김이나 고구마튀김 등 다양한 튀김 요리가 있어 바삭한 식감을 즐길 수 있습니다.
# 5. **호떡**: 달콤한 채소나 견과류가 들어간 호떡은 특히 겨울철에 인기 있는 간식입니다.
#
# 이 외에도 많은 다양한 거리 음식이 있으니, 방문해보시면 여러 가지를 맛볼 수 있습니다!

# %% [markdown]
# # RedisSemanticCache

# %%
REDIS_URL = os.environ['REDIS_URL']

# %%
from dotenv import load_dotenv
import os
load_dotenv()

from langchain_core.globals import set_llm_cache
from langchain_redis import RedisSemanticCache          # 변경
from langchain_openai import ChatOpenAI, OpenAIEmbeddings

# %%
semantic_cache = RedisSemanticCache(
    redis_url=REDIS_URL,
    embeddings=OpenAIEmbeddings(model="text-embedding-3-small"),  # 파라미터명 변경
    distance_threshold=0.2                                         # 파라미터명 변경
)

set_llm_cache(semantic_cache)
llm = ChatOpenAI(model="gpt-4o-mini")
print("RedisSemanticCache 연결 완료")
# Out:
# RedisSemanticCache 연결 완료

# %%
response = llm.invoke([HumanMessage(content="코스피 지수란 무엇인가요? 한 문장으로 답해주세요.")])
print(response.content)
# Out:
# 코스피 지수는 한국거래소에 상장된 기업들의 주식 가격을 바탕으로 산출되는 한국의 대표적인 주식 시장 지수입니다.

# %%
response = llm.invoke([HumanMessage(content="코스피 지수란 무엇인가요? 한 문장으로 답해주세요.")])
print(response.content)
# Out:
# 코스피 지수는 한국거래소에 상장된 기업들의 주식 가격을 바탕으로 산출되는 한국의 대표적인 주식 시장 지수입니다.

# %%
response = llm.invoke([HumanMessage(content="코스피가 뭔지 간단히 설명해줘.")])
print(response.content)
# Out:
# 코스피 지수는 한국거래소에 상장된 기업들의 주식 가격을 바탕으로 산출되는 한국의 대표적인 주식 시장 지수입니다.

# %%
semantic_cache = RedisSemanticCache(
    redis_url=REDIS_URL,
    embeddings=OpenAIEmbeddings(model="text-embedding-3-small"),  # 파라미터명 변경
    distance_threshold=0.02,
    ttl=3600
)
set_llm_cache(semantic_cache)

# %%
semantic_cache.clear()

# %%
messages = [
    ("system", "너는 투자리포트 작가이다."),
    ("human",  "AAPL 최근 분기 핵심 포인트 세 가지를 요약해줘.")
]
resp = llm.invoke(messages)   # 동일 입력이면 Redis에서 바로 HIT
print(resp.content)
# Out:
# Apple Inc. (AAPL)의 최근 분기 핵심 포인트 세 가지는 다음과 같습니다:
#
# 1. **매출 성장**: AAPL은 최근 분기 실적 발표에서 전년 대비 매출이 증가한 것으로 보고되었습니다. 특히, 아이폰 매출이 강세를 보이며 전체 매출 성장에 기여했습니다. 새로운 모델 출시와 강력한 소비자 수요가 관련된 요소로 분석됩니다.
#
# 2. **서비스 부문 확장**: 회사의 서비스 부문, 즉 Apple Music, Apple TV+, iCloud 등은 지속적인 성장세를 보여주고 있습니다. 이 분야의 매출이 큰 폭으로 증가하여 전체 수익 구조에서 중요한 역할을 하고 있습니다.
#
# 3. **주주 환원 정책**: AAPL은 주주에게 배당금 지급을 늘리고 자사주 매입을 이어가는 등 주주 환원 정책을 강화하고 있습니다. 이를 통해 투자자 신뢰도를 높이고, 주가 안정성을 유지하고자 하는 전략을 취하고 있습니다.
#
# 이러한 요소들은 AAPL의 지속적인 성장 가능성을 시사하며, 투자자들에게 긍정적인 신호로 작용할 수 있습니다.

# %%
response = llm.invoke([HumanMessage(content="코스닥에 대해 간단히 설명해줘.")])
print(response.content)
# Out:
# 코스닥(KOSDAQ)은 대한민국의 주식 시장 중 하나로, 주로 중소기업과 벤처기업의 성장 촉진을 목표로 설계된 거래소입니다. 코스닥은 'Korea Securities Dealers Automated Quotations'의 약자로, 1996년에 설립되었습니다.
#
# 코스닥 시장은 기술 기반의 기업들이 많이 상장되어 있으며, 상대적으로 높은 성장 가능성을 가진 기업들이 주로 거래됩니다. 이로 인해 코스닥은 한국의 스타트업과 혁신적인 중소기업들에 대한 투자 기회를 제공하는 중요한 시장으로 자리 잡고 있습니다.
#
# 또한 코스닥은 한국거래소(KRX)와의 연계로 운영되며, 상장 요건이 코스피에 비해 상대적으로 완화되어 있어 많은 새로운 기업들이 쉽게 참여할 수 있는 장점이 있습니다.

# %%
import time
# 시간 측정 헬퍼 함수
def ask(question: str) -> tuple:
    start = time.perf_counter()
    response = llm.invoke([HumanMessage(content=question)])
    elapsed = time.perf_counter() - start
    return response.content, elapsed

print("환경 설정 완료")
# Out:
# 환경 설정 완료

# %%
question_pairs = [
    ("코스피 지수란 무엇인가요?",       "최초 API 호출"),
    ("코스피 지수란 무엇인가요?",       "정확 일치 캐시"),
    ("코스피가 뭔지 설명해줘.",         "시맨틱 캐시 (유사 질문 1)"),
    ("KOSPI 지수에 대해 알려주세요.",   "시맨틱 캐시 (유사 질문 2)"),
]

print("[ RedisSemanticCache 테스트 ]")
for q, label in question_pairs:
    answer, elapsed = ask(q)
    print(f"{label}: {elapsed*1000:.0f}ms | 질문: {q}")
print()
print("응답:", answer[:50], "...")
# Out:
# [ RedisSemanticCache 테스트 ]
# 최초 API 호출: 4718ms | 질문: 코스피 지수란 무엇인가요?
# 정확 일치 캐시: 714ms | 질문: 코스피 지수란 무엇인가요?
# 시맨틱 캐시 (유사 질문 1): 661ms | 질문: 코스피가 뭔지 설명해줘.
# 시맨틱 캐시 (유사 질문 2): 6309ms | 질문: KOSPI 지수에 대해 알려주세요.
#
# 응답: KOSPI(Korea Composite Stock Price Index)는 한국의 주식시장 ...

# %%
response = llm.invoke([HumanMessage(content="코스닥에 대해 간단히 설명해줘.")])
print(response.content)
# Out:
# 코스피(KOSPI) 지수는 대한민국의 주식 시장을 대표하는 주가지수로, "Korea Composite Stock Price Index"의 약자입니다. 코스피 지수는 한국 거래소에 상장된 주식의 전반적인 가격 변동을 나타내는 지표로, 한국 경제의 건강 상태와 주식 시장의 동향을 파악하는 데 중요한 역할을 합니다.
#
# 코스피 지수는 특정 기준일의 주가를 기준으로 하여 그 이후의 주가 변동을 반영하여 계산됩니다. 주식 시장에 상장된 기업들이 발행한 주식의 시가 총액을 바탕으로 하며, 주식 시장의 전반적인 흐름을 보여줍니다. 코스피 지수가 상승하면 주가가 전반적으로 상승하고 있음을 나타내고, 하락하면 반대로 주가가 하락하고 있음을 의미합니다.
#
# 코스피 지수는 투자자, 경제학자, 기관 투자자 등 다양한 이해관계자들이 경제 및 시장 분석에 활용하며, 한국의 경제 상황을 이해하는 중요한 도구 중 하나입니다.
