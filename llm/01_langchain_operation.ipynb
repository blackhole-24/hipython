# %%
from dotenv import load_dotenv
import os

load_dotenv()
# Out:
# True

# %% [markdown]
# # 처리 방식
# invoke()
# batch()
# stream()

# %% [markdown]
# # invoke [단일 입력 단일 응답]

# %%
from langchain_openai import ChatOpenAI
from langchain_core.messages import HumanMessage

llm = ChatOpenAI(model="gpt-4o-mini")

# invoke() - 단일 입력, 단일 응답 (동기)
response = llm.invoke("삼성전자 주가에 영향을 주는 요인은?")
print(response.content)
# Out:
# 삼성전자 주가에 영향을 주는 요인은 여러 가지가 있습니다. 주요 요인은 다음과 같습니다:
#
# 1. **실적 발표**: 삼성전자의 분기 및 연간 실적 발표는 주가에 큰 영향을 미칩니다. 매출, 영업이익, 순이익 등의 지표가 예상보다 좋거나 나쁠 경우 주가가 크게 변동할 수 있습니다.
#
# 2. **경제 지표**: 한국 및 글로벌 경제 지표(예: GDP 성장률, 실업률, 소비자 물가 상승률 등)는 주가에 영향을 미칩니다. 특히 반도체와 전자 제품의 수요가 많아지는 시기에 주가 상승 가능성이 높습니다.
#
# 3. **산업 트렌드**: 반도체, 스마트폰, 가전 등 삼성전자가 주력으로 하는 산업의 트렌드와 기술 발전은 주가에 큰 영향을 미칩니다. 인공지능, 5G, 전기차와 관련된 기술 발전은 긍정적인 영향을 미칠 수 있습니다.
#
# 4. **경쟁사 동향**: 애플, 인텔, TSMC 등 주요 경쟁사들의 실적이나 새로운 제품 출시 또한 삼성전자 주가에 영향을 미칠 수 있습니다.
#
# 5. **글로벌 무역 및 정치적 요인**: 미중 무역 전쟁, 국제 관계, 규제 등의 정치적 요인도 주가에 영향을 미칠 수 있습니다.
#
# 6. **환율 변동**: 삼성전자는 수출 중심의 기업이기 때문에 원화와 달러 간의 환율 변동이 중요한 영향을 미칠 수 있습니다.
#
# 7. **투자자의 심리**: 시장의 전반적인 투자 심리나 ETF, 외국인 투자자의 매매 동향도 주가에 영향을 미치는 요소입니다.
#
# 이 밖에도 기술적 분석, 시장 뉴스, 경제 정책 등의 다양한 요인이 주가에 영향을 줄 수 있습니다.

# %% [markdown]
# # batch() - 여러 입력을 한 번에 처리

# %%
# batch() - 여러 입력을 한 번에 처리 (동기)
# 중복 토큰을 줄여 묶어 처리 → 비용 절감 효과
questions = [
    "삼성전자 주가에 영향을 주는 요인은?",
    "코스피 지수란 무엇인가?",
    "ETF와 펀드의 차이는?"
]
responses = llm.batch(questions)
for r in responses:
    print(r.content)
    print()
# Out:
# 삼성전자 주가에 영향을 주는 여러 요인이 있습니다. 주요 요인은 다음과 같습니다:
#
# 1. **세계 경제 상황**: 글로벌 경제 성장률, 인플레이션, 통화 정책 등의 변화는 소비자 수요에 영향을 미쳐 삼성전자의 실적에 직접적인 영향을 미칩니다.
#
# 2. **반도체 산업 사이클**: 삼성전자는 세계적인 반도체 제조업체이기 때문에, 반도체 수요와 공급의 변화, 가격 변동 등이 주가에 큰 영향을 미칩니다.
#
# 3. **경쟁사 동향**: 애플, 화웨이, 대만의 TSMC 등 경쟁사의 새로운 제품 출시나 기술 발전 등이 삼성전자의 시장 점유율과 수익성에 영향을 줄 수 있습니다.
#
# 4. **환율**: 삼성전자는 해외 시장에 많은 의존을 하고 있기 때문에 원/달러 환율과 같은 환율 변동은 수익성과 직결될 수 있습니다.
#
# 5. **기술 혁신**: 새로운 기술이나 제품 혁신 소식, 연구 개발 투자 결과는 삼성전자의 성장 가능성에 영향을 미쳐 주가에 반영될 수 있습니다.
#
# 6. **정책 및 규제**: 각국의 규제 변화, 특히 기술 및 통신 관련 법률, 무역 정책 등이 삼성전자의 비즈니스 환경에 영향을 줄 수 있습니다.
#
# 7. **실적 발표**: 분기별 실적 발표는 주가에 큰 영향을 미칩니다. 실적이 예상보다 좋거나 나쁘면 주가가 큰 변동성을 보일 수 있습니다.
#
# 8. **투자자 심리**: 시장의 전반적인 투자 심리, 특히 대형 기술주에 대한 수요나 투자자의 기대감이 주가에 영향을 미칩니다.
#
# 이 외에도 다양한 외부 요인들이 복합적으로 작용하여 삼성전자의 주가에 영향을 미치게 됩니다.
#
# 코스피(KOSPI)는 "Korea Composite Stock Price Index"의 약자로, 한국의 대표적인 주식 시장 지수입니다. 한국거래소(KRX)에서 상장된 모든 주식의 시가 총액을 기준으로 계산되며, 한국의 경제와 주식 시장의 전반적인 동향을 나타내는 지표로 사용됩니다.
#
# 코스피 지수는 1980년 1월 4일에 100포인트를 기준으로 시작하였으며, 코스피에 포함되는 종목들은 시가 총액을 기준으로 가중치가 부여되어 지수가 산출됩니다. 즉, 규모가 큰 기업의 주가는 코스피에 더 큰 영향을 미치게 됩니다.
#
# 코스피는 투자자들이 한국 주식 시장의 흐름을 파악하고, 경제 상황을 평가하는 데 중요한 역할을 하며, 국내외 투자자들이 한국 시장에 대한 투자 결정을 내리는 데 참고하는 지수입니다.
#
# ETF(상장지수펀드)와 전통적인 펀드는 몇 가지 주요 차이점이 있습니다. 아래에 이 두 가지 투자 수단의 주요 차이점을 정리해 보겠습니다.
#
# 1. **상장 여부**:
#    - **ETF**: 주식처럼 증권거래소에 상장되어 있어, 실시간으로 거래가 가능합니다. 투자자들은 시장 가격에 따라 언제든지 매매할 수 있습니다.
#    - **펀드**: 일반적으로 하루에 한 번, 장 마감 후에 가격이 결정되는 NAV(순자산가치)로 거래됩니다. 따라서 투자자는 같은 날에 매매할 수 없고, 주문이 다음 거래일에 실행됩니다.
#
# 2. **비용 구조**:
#    - **ETF**: 일반적으로 관리 수수료가 낮고, 거래 시 브로커 수수료가 발생할 수 있습니다. 그러나 비율에서 발생하는 경비비용이 낮아서 장기적으로 수익률에서 유리할 수 있습니다.
#    - **펀드**: 관리 수수료와 함께 판매 수수료(로딩)가 부과될 수 있으며, 비용 구조가 상대적으로 복잡합니다.
#
# 3. **Tax Efficiency (세금 효율성)**:
#    - **ETF**: 구조적으로 매매가 이루어질 때 자본 이득세가 발생하지 않아 세금 효율성이 높습니다.
#    - **펀드**: 매매가 이루어질 때 자본 이득이 발생할 수 있어 세금 부담이 클 수 있습니다.
#
# 4. **투자 전략**:
#    - **ETF**: 일반적으로 특정 지수나 자산군을 추적하는 데 집중하며, 패시브 투자 전략에 많이 사용됩니다.
#    - **펀드**: 액티브 투자 전략을 사용하는 경우도 많아, 펀드 매니저가 직접 종목을 선택하고 시장을 분석하여 투자 결정을 내립니다.
#
# 5. **투자 최소금액**:
#    - **ETF**: 최소 투자 금액은 보통 한 주(share)로, 이는 상대적으로 낮습니다.
#    - **펀드**: 기본적으로 최소 투자 금액이 설정되어 있으며, 일반적으로 몇 백만 원 이상으로 설정될 수 있습니다.
#
# 이러한 차이점들 때문에 투자자들은 자신의 투자 목표나 전략에 따라 ETF 또는 전통적인 펀드를 선택할 수 있습니다.

# %% [markdown]
# # stream() - 실시간 스트리밍 출력

# %%
# stream() - 실시간 스트리밍 출력 (토큰 단위로 출력)
for chunk in llm.stream("환율이 수출 기업에 미치는 영향은?"):
    print(chunk.content, end="", flush=True)
# Out:
# 환율은 수출 기업에 여러 가지 방식으로 영향을 미칩니다. 주요한 영향을 정리하면 다음과 같습니다:
#
# 1. **가격 경쟁력**: 환율이 하락(자국 통화의 가치가 상승)하면, 자국의 제품이 해외에서 비싸지게 됩니다. 이로 인해 수출 경쟁력이 떨어질 수 있습니다. 반대로, 자국 통화가 평가절하(환율 상승)되면 해외에서 자국 제품의 가격이 상대적으로 저렴해져 수출이 증가할 가능성이 있습니다.
#
# 2. **이익 변동**: 수출 기업이 외화를 수익으로 가질 경우, 환율의 변동은 이익에 큰 영향을 미칠 수 있습니다. 외화 수익이 자국 통화로 환산될 때 환율이 높으면 높은 수익을, 반대로 낮으면 낮은 수익을 얻게 됩니다.
#
# 3. **비용 요인**: 수출 기업이 해외에서 원재료나 부품을 구매하는 경우, 환율 변화는 원재료 비용에 영향을 미칩니다. 자국 통화가 강세를 보일 경우 해외 구매비용이 상대적으로 줄어들게 되며, 이는 전체 비용 절감으로 이어질 수 있습니다.
#
# 4. **계약 및 가격 설정**: 환율 변동은 계약 체결 시의 가격 설정에도 영향을 미칩니다. 가격을 고정하는 계약을 체결할 경우, 이후 환율 변화로 인해 이익률에 변동이 생길 수 있습니다.
#
# 5. **리스크 관리**: 환율 변동에 따른 리스크를 관리하기 위해 파생상품이나 헤지 전략을 활용하는 기업들이 많습니다. 하지만 이러한 추가 비용이 기업의 이익에 영향을 줄 수 있습니다.
#
# 결론적으로, 환율은 수출 기업의 가격 경쟁력, 이익, 비용 구조 및 리스크 관리 전략에 중요한 영향을 미치므로, 기업은 환율 변동에 신중하게 대응해야 합니다.

# %% [markdown]
# # 동기 vs. 비동기

# %%
import asyncio
import time
from langchain_openai import ChatOpenAI
#from langchain_core.messages import HumanMessage

#llm = ChatOpenAI(model="gpt-4o-mini")

questions = [f"주식 투자 팁 {i}번째" for i in range(10)]

# 비동기 병렬 처리
async def invoke_async(question): # 각 프롬프트 1개 처리
    response = await llm.ainvoke(question)
    return response.content

async def invoke_parallel(questions): # 다수의 프롬프트 목록을 처리
    tasks = [invoke_async(q) for q in questions]
    return await asyncio.gather(*tasks)

# %%
res = await invoke_async(questions[0])
#print(res)

# %% [markdown]
# # 비동기 실행 시간 측정

# %%
# 비동기 실행 시간 측정
start = time.perf_counter()
results = await invoke_parallel(questions)
end = time.perf_counter()
print(f"비동기 처리: {end - start:.2f}초")   # 약 5~6초
# Out:
# 비동기 처리: 7.39초

# %%
# 동기 실행 시간 측정
start = time.perf_counter()
for q in questions:
    response = llm.invoke(q) #동기호출
end = time.perf_counter()
print(f"동기 처리: {end - start:.2f}초")     # 약 40~50초
# Out:
# 동기 처리: 57.72초

# %%
results
# Out:
# ["주식 투자에 관한 0번째 팁은 '기초 지식 습득'입니다. 주식 시장에 대한 이해가 부족하다면, 투자 결정을 내리기 전에 기본적인 개념과 원리를 배우는 것이 중요합니다. 다음은 기초 지식을 쌓기 위해 고려해야 할 몇 가지 요소입니다:\n\n1. **주식의 기본 이해**: 주식이 무엇인지, 주식 시장이 어떻게 운영되는지, 기업이 주식을 발행하는 이유 등을 알아보세요.\n\n2. **재무제표 분석**: 기업의 재무제표를 이해하고 분석하는 방법을 배우는 것이 중요합니다. 수익, 자산, 부채 등 다양한 지표를 통해 기업의 건강성을 파악할 수 있습니다.\n\n3. **투자 전략**: 장기 투자, 단기 매매, 배당 투자 등 다양한 투자 전략을 조사하고 자신에게 맞는 전략을 선택하세요.\n\n4. **리스크 관리**: 투자에는 항상 리스크가 따르므로, 손실을 최소화하고 리스크를 관리하는 방법을 배우는 것이 중요합니다.\n\n5. **시장 동향 파악**: 경제 뉴스, 산업 동향, 정치적 이슈 등이 주식 시장에 미치는 영향을 이해하고 주의 깊게 살펴보세요.\n\n기초 지식을 쌓은 후에는 실전 투자에 나서거나, 작은 금액으로 시작하여 경험을 쌓아가는 것이 좋습니다. 항상 신중하게 접근하세요!",
#  '주식 투자 팁 첫 번째는 **분산 투자**입니다. 분산 투자는 여러 종목이나 자산 클래스에 투자하여 위험을 줄이는 전략입니다. 특정 주식이나 산업에 모든 자금을 집중하면, 해당 주식이나 산업의 부진으로 큰 손실을 볼 수 있습니다. \n\n따라서, 다양한 산업, 지역, 자산군에 투자하여 포트폴리오의 리스크를 최소화하는 것이 중요합니다. 예를 들어, 기술주, 소비재, 헬스케어 등 서로 다른 업종의 주식에 투자함으로써, 한 분야의 변동성에 영향을 덜 받을 수 있습니다. \n\n그리고 분산 투자에는 주식 외에도 채권, 상품, 부동산 등 다양한 자산을 포함시킬 수 있다는 점을 기억하세요!',
#  '주식 투자에 관한 두 번째 팁은 "분산 투자"입니다. \n\n### 분산 투자\n1. **리스크 감소**: 여러 종목에 투자함으로써 특정 종목의 변동성에 의한 리스크를 줄일 수 있습니다. 한 종목이 부진해도 다른 종목에서 얻은 수익이 이를 상쇄할 수 있습니다.\n   \n2. **산업 및 지역 분산**: 다양한 산업과 지역에 투자하면 경제 전반의 영향을 덜 받을 수 있습니다. 예를 들어, 기술주, 헬스케어주, 소비재주 등을 혼합하여 투자하면 더욱 안정적일 수 있습니다.\n   \n3. **자산 클래스 분산**: 주식뿐만 아니라 채권, 부동산, 금 등 다양한 자산 클래스에 투자함으로써 포트폴리오의 안정성을 높일 수 있습니다.\n\n4. **투자 비율 조정**: 각 자산이나 종목에 배분하는 비율을 조정하여 리스크와 수익률을 균형있게 관리할 수 있습니다. \n\n분산 투자는 안정적인 수익을 추구하는 투자자에게 매우 중요한 전략입니다. 적절한 분산을 통해 더욱 낮은 리스크로 주식 투자에 임해보세요!',
#  '주식 투자에서 중요한 세 번째 팁은 **분산 투자**입니다. \n\n분산 투자는 한 가지 자산이나 산업에만 투자하는 대신, 여러 가지 자산에 투자하여 리스크를 줄이는 전략입니다. 이렇게 하면 특정 주식이나 산업이 악 영향을 받을 때 전체 포트폴리오에 미치는 영향을 최소화할 수 있습니다. \n\n예를 들어, 기술주, 헬스케어, 소비재, 해외 주식 등 다양한 분야에 투자함으로써 시장 변동성에 대한 저항력을 높일 수 있습니다. \n\n추가로, 투자하는 자산의 종류(주식, 채권, 부동산 등) 또한 다양하게 구성함으로써 리스크 관리에 효과적일 수 있습니다. \n\n이와 같은 분산 투자는 장기적으로 안정적인 수익을 추구하는 중요한 전략 중 하나입니다.',
#  '주식 투자에 관한 네 번째 팁은 **장기적인 관점을 갖는 것**입니다. 주식 시장은 단기적으로 변동성이 클 수 있지만, 장기적으로는 기업의 성장과 경제 전반의 발전에 따라 주가가 상승하는 경향이 있습니다. 따라서 짧은 시기에 일어나는 시장의 변화를 지나치게 신경 쓰기보다는 자신의 투자 목표에 따라 장기적으로 보유할 수 있는 종목을 선택하는 것이 중요합니다.\n\n**추가 팁**:\n1. **정기적인 재조정**: 포트폴리오를 주기적으로 점검하고, 필요에 따라 조정합니다.\n2. **적립식 투자**: 정해진 금액을 정기적으로 투자하는 방법으로, 시장의 타이밍을 맞추기보다는 분산투자의 효과를 높일 수 있습니다.\n3. **정보 습득**: 투자자 자신이 참여하고 있는 산업이나 기업에 대한 최신 정보를 지속적으로 공부하고 파악합니다.\n\n장기적인 투자는 변동성에 덜 영향을 받아 안정적인 수익을 추구할 수 있는 좋은 방법입니다.',
#  '주식 투자에 대한 다섯 번째 팁은 **장기 투자 전략을 세우는 것입니다**. \n\n장기 투자 전략은 주식 시장의 단기 변동성에 휘둘리지 않고, 기업의 기본적 가치에 집중하는 방법입니다. 이를 통해 다음과 같은 이점을 누릴 수 있습니다:\n\n1. **복리 효과**: 장기간에 걸쳐 투자하면 복리의 힘을 통해 수익이 증가할 수 있습니다.\n2. **심리적 안정**: 단기적인 가격 변동에 신경 쓰지 않고 안정된 마음으로 투자를 지속할 수 있습니다.\n3. **시장 변동 불안정성 완화**: 급격한 시장 변화에도 불구하고 장기적인 트렌드를 볼 수 있게 됩니다.\n\n장기 투자 전략을 수립할 때는 투자 목표를 명확히 하고, 분산 투자 및 포트폴리오 재조정 계획을 함께 세우는 것이 좋습니다. 이러한 접근법을 통해 더 큰 수익을 기대할 수 있습니다.',
#  '주식 투자 팁의 여섯 번째는 **장기적인 관점에서 투자하기**입니다. 단기적인 시장 변동에 휘둘리지 않고, 기업의 성장 가능성과 장기적인 전략을 고려하여 투자를 결정하는 것이 중요합니다. 장기 투자는 시장의 변동성을 완화하고, 복리 효과를 누리는 데 유리합니다. 또한, 주식 시장은 시간이 지남에 따라 성장하는 경향이 있으므로, 인내심을 가지고 기다리는 것이 좋습니다. \n\n추가적으로, 장기 투자 시에도 주기적으로 포트폴리오를 점검하고 필요에 따라 조정하는 것도 중요합니다. 이렇게 하면 시장 상황 변화에 대응하면서도 장기적인 목표를 유지할 수 있습니다.',
#  '주식 투자에 대한 팁 중 7번째는 **다양한 정보원 활용하기**입니다.\n\n주식 시장의 움직임을 이해하고 성공적인 투자를 하기 위해서는 다양한 정보원을 활용하는 것이 중요합니다. 다만, 정보를 얻을 때는 신뢰할 수 있는 출처에서 확인하고, 여러 관점을 고려하는 것이 좋습니다. 다음과 같은 정보를 참고할 수 있습니다:\n\n1. **재무제표 분석**: 기업의 재무제표를 통해 수익성, 안정성, 성장성을 평가할 수 있습니다.\n2. **뉴스 및 경제 지표**: 경제 전반의 흐름과 관련된 뉴스 및 경제 지표를 지속적으로 확인하여 시장의 변동성을 파악하세요.\n3. **분석 리포트**: 주식 시장의 전문가들이 작성한 분석 리포트를 통해 깊이 있는 통찰을 얻을 수 있습니다.\n4. **소셜 미디어와 투자 커뮤니티**: 다른 투자자들과 의견을 나누고, 최근의 트렌드를 파악하기 위해 활용할 수 있습니다.\n\n이러한 다양한 정보를 바탕으로 결정을 내리면, 보다 체계적이고 신뢰할 수 있는 투자를 할 수 있습니다. 정보를 선별하여 분석하고, 자신의 투자 스타일에 맞게 적용하는 것이 중요합니다.',
#  '주식 투자에 대한 8번째 팁은 **감정의 통제**입니다. \n\n주식 시장은 감정이 크게 작용하는 곳입니다. 특히, 가격이 급등하거나 급락할 때 개인 투자자는 불안하거나 지나치게 기뻐할 수 있습니다. 이러한 감정이 투자 결정을 흐리게 만들어 잘못된 선택을 하게 할 수 있습니다. \n\n**감정 통제의 팁:**\n\n1. **계획 세우기:** 미리 투자 계획을 세우고 목표를 설정하세요. 어떤 상황에도 이 계획을 유지하도록 노력하세요.\n2. **분산 투자:** 여러 자산에 분산 투자하여 특정 종목이나 시장의 변동성에 덜 영향을 받도록 하세요.\n3. **손실 수용:** 손실은 투자에서 자연스러운 부분입니다. 손실을 받더라도 감정적으로 대응하지 말고 냉정하게 판단하세요.\n4. **정보 업데이트:** 시장과 기업의 상황을 꾸준히 모니터링하며 적절한 시점에 대응할 수 있는 능력을 기르세요.\n5. **장기적 시각 유지:** 단기적인 변동성에 휘둘리지 않고 장기 목표에 집중하세요.\n\n이러한 방법을 통해 감정을 통제하고 더욱 안정적인 투자 결정을 내릴 수 있습니다.',
#  '주식 투자에 관한 아홉 번째 팁은 "장기적인 관점으로 투자하라"입니다.短期적인 시장 변동성에 휘둘리지 않고, 기업의 기본적인 가치를 평가하여 장기적으로 성장할 것으로 예상되는 종목에 투자하세요. \n\n장기 투자는 주식 시장의 변동성을 극복하고, 복리 효과를 통해 자산을 증대시킬 수 있는 좋은 방법입니다. 이를 위해 기업의 경영 상태, 산업 트렌드, 경제 전반의 흐름 등을 분석하고, 기초적인 재무 지표를 이해하는 것이 중요합니다.\n\n주식 투자에서 일관된 전략을 유지하고, 정기적으로 투자 포트폴리오를 점검하며, 필요에 따라 조정을 하는 것도 잊지 마십시오.']

# %%
for index, content in enumerate(results):
  print(f"{index}, content:{content}")
# Out:
# 0, content:주식 투자에 관한 0번째 팁은 '기초 지식 습득'입니다. 주식 시장에 대한 이해가 부족하다면, 투자 결정을 내리기 전에 기본적인 개념과 원리를 배우는 것이 중요합니다. 다음은 기초 지식을 쌓기 위해 고려해야 할 몇 가지 요소입니다:
#
# 1. **주식의 기본 이해**: 주식이 무엇인지, 주식 시장이 어떻게 운영되는지, 기업이 주식을 발행하는 이유 등을 알아보세요.
#
# 2. **재무제표 분석**: 기업의 재무제표를 이해하고 분석하는 방법을 배우는 것이 중요합니다. 수익, 자산, 부채 등 다양한 지표를 통해 기업의 건강성을 파악할 수 있습니다.
#
# 3. **투자 전략**: 장기 투자, 단기 매매, 배당 투자 등 다양한 투자 전략을 조사하고 자신에게 맞는 전략을 선택하세요.
#
# 4. **리스크 관리**: 투자에는 항상 리스크가 따르므로, 손실을 최소화하고 리스크를 관리하는 방법을 배우는 것이 중요합니다.
#
# 5. **시장 동향 파악**: 경제 뉴스, 산업 동향, 정치적 이슈 등이 주식 시장에 미치는 영향을 이해하고 주의 깊게 살펴보세요.
#
# 기초 지식을 쌓은 후에는 실전 투자에 나서거나, 작은 금액으로 시작하여 경험을 쌓아가는 것이 좋습니다. 항상 신중하게 접근하세요!
# 1, content:주식 투자 팁 첫 번째는 **분산 투자**입니다. 분산 투자는 여러 종목이나 자산 클래스에 투자하여 위험을 줄이는 전략입니다. 특정 주식이나 산업에 모든 자금을 집중하면, 해당 주식이나 산업의 부진으로 큰 손실을 볼 수 있습니다.
#
# 따라서, 다양한 산업, 지역, 자산군에 투자하여 포트폴리오의 리스크를 최소화하는 것이 중요합니다. 예를 들어, 기술주, 소비재, 헬스케어 등 서로 다른 업종의 주식에 투자함으로써, 한 분야의 변동성에 영향을 덜 받을 수 있습니다.
#
# 그리고 분산 투자에는 주식 외에도 채권, 상품, 부동산 등 다양한 자산을 포함시킬 수 있다는 점을 기억하세요!
# 2, content:주식 투자에 관한 두 번째 팁은 "분산 투자"입니다.
#
# ### 분산 투자
# 1. **리스크 감소**: 여러 종목에 투자함으로써 특정 종목의 변동성에 의한 리스크를 줄일 수 있습니다. 한 종목이 부진해도 다른 종목에서 얻은 수익이 이를 상쇄할 수 있습니다.
#
# 2. **산업 및 지역 분산**: 다양한 산업과 지역에 투자하면 경제 전반의 영향을 덜 받을 수 있습니다. 예를 들어, 기술주, 헬스케어주, 소비재주 등을 혼합하여 투자하면 더욱 안정적일 수 있습니다.
#
# 3. **자산 클래스 분산**: 주식뿐만 아니라 채권, 부동산, 금 등 다양한 자산 클래스에 투자함으로써 포트폴리오의 안정성을 높일 수 있습니다.
#
# 4. **투자 비율 조정**: 각 자산이나 종목에 배분하는 비율을 조정하여 리스크와 수익률을 균형있게 관리할 수 있습니다.
#
# 분산 투자는 안정적인 수익을 추구하는 투자자에게 매우 중요한 전략입니다. 적절한 분산을 통해 더욱 낮은 리스크로 주식 투자에 임해보세요!
# 3, content:주식 투자에서 중요한 세 번째 팁은 **분산 투자**입니다.
#
# 분산 투자는 한 가지 자산이나 산업에만 투자하는 대신, 여러 가지 자산에 투자하여 리스크를 줄이는 전략입니다. 이렇게 하면 특정 주식이나 산업이 악 영향을 받을 때 전체 포트폴리오에 미치는 영향을 최소화할 수 있습니다.
#
# 예를 들어, 기술주, 헬스케어, 소비재, 해외 주식 등 다양한 분야에 투자함으로써 시장 변동성에 대한 저항력을 높일 수 있습니다.
#
# 추가로, 투자하는 자산의 종류(주식, 채권, 부동산 등) 또한 다양하게 구성함으로써 리스크 관리에 효과적일 수 있습니다.
#
# 이와 같은 분산 투자는 장기적으로 안정적인 수익을 추구하는 중요한 전략 중 하나입니다.
# 4, content:주식 투자에 관한 네 번째 팁은 **장기적인 관점을 갖는 것**입니다. 주식 시장은 단기적으로 변동성이 클 수 있지만, 장기적으로는 기업의 성장과 경제 전반의 발전에 따라 주가가 상승하는 경향이 있습니다. 따라서 짧은 시기에 일어나는 시장의 변화를 지나치게 신경 쓰기보다는 자신의 투자 목표에 따라 장기적으로 보유할 수 있는 종목을 선택하는 것이 중요합니다.
#
# **추가 팁**:
# 1. **정기적인 재조정**: 포트폴리오를 주기적으로 점검하고, 필요에 따라 조정합니다.
# 2. **적립식 투자**: 정해진 금액을 정기적으로 투자하는 방법으로, 시장의 타이밍을 맞추기보다는 분산투자의 효과를 높일 수 있습니다.
# 3. **정보 습득**: 투자자 자신이 참여하고 있는 산업이나 기업에 대한 최신 정보를 지속적으로 공부하고 파악합니다.
#
# 장기적인 투자는 변동성에 덜 영향을 받아 안정적인 수익을 추구할 수 있는 좋은 방법입니다.
# 5, content:주식 투자에 대한 다섯 번째 팁은 **장기 투자 전략을 세우는 것입니다**.
#
# 장기 투자 전략은 주식 시장의 단기 변동성에 휘둘리지 않고, 기업의 기본적 가치에 집중하는 방법입니다. 이를 통해 다음과 같은 이점을 누릴 수 있습니다:
#
# 1. **복리 효과**: 장기간에 걸쳐 투자하면 복리의 힘을 통해 수익이 증가할 수 있습니다.
# 2. **심리적 안정**: 단기적인 가격 변동에 신경 쓰지 않고 안정된 마음으로 투자를 지속할 수 있습니다.
# 3. **시장 변동 불안정성 완화**: 급격한 시장 변화에도 불구하고 장기적인 트렌드를 볼 수 있게 됩니다.
#
# 장기 투자 전략을 수립할 때는 투자 목표를 명확히 하고, 분산 투자 및 포트폴리오 재조정 계획을 함께 세우는 것이 좋습니다. 이러한 접근법을 통해 더 큰 수익을 기대할 수 있습니다.
# 6, content:주식 투자 팁의 여섯 번째는 **장기적인 관점에서 투자하기**입니다. 단기적인 시장 변동에 휘둘리지 않고, 기업의 성장 가능성과 장기적인 전략을 고려하여 투자를 결정하는 것이 중요합니다. 장기 투자는 시장의 변동성을 완화하고, 복리 효과를 누리는 데 유리합니다. 또한, 주식 시장은 시간이 지남에 따라 성장하는 경향이 있으므로, 인내심을 가지고 기다리는 것이 좋습니다.
#
# 추가적으로, 장기 투자 시에도 주기적으로 포트폴리오를 점검하고 필요에 따라 조정하는 것도 중요합니다. 이렇게 하면 시장 상황 변화에 대응하면서도 장기적인 목표를 유지할 수 있습니다.
# 7, content:주식 투자에 대한 팁 중 7번째는 **다양한 정보원 활용하기**입니다.
#
# 주식 시장의 움직임을 이해하고 성공적인 투자를 하기 위해서는 다양한 정보원을 활용하는 것이 중요합니다. 다만, 정보를 얻을 때는 신뢰할 수 있는 출처에서 확인하고, 여러 관점을 고려하는 것이 좋습니다. 다음과 같은 정보를 참고할 수 있습니다:
#
# 1. **재무제표 분석**: 기업의 재무제표를 통해 수익성, 안정성, 성장성을 평가할 수 있습니다.
# 2. **뉴스 및 경제 지표**: 경제 전반의 흐름과 관련된 뉴스 및 경제 지표를 지속적으로 확인하여 시장의 변동성을 파악하세요.
# 3. **분석 리포트**: 주식 시장의 전문가들이 작성한 분석 리포트를 통해 깊이 있는 통찰을 얻을 수 있습니다.
# 4. **소셜 미디어와 투자 커뮤니티**: 다른 투자자들과 의견을 나누고, 최근의 트렌드를 파악하기 위해 활용할 수 있습니다.
#
# 이러한 다양한 정보를 바탕으로 결정을 내리면, 보다 체계적이고 신뢰할 수 있는 투자를 할 수 있습니다. 정보를 선별하여 분석하고, 자신의 투자 스타일에 맞게 적용하는 것이 중요합니다.
# 8, content:주식 투자에 대한 8번째 팁은 **감정의 통제**입니다.
#
# 주식 시장은 감정이 크게 작용하는 곳입니다. 특히, 가격이 급등하거나 급락할 때 개인 투자자는 불안하거나 지나치게 기뻐할 수 있습니다. 이러한 감정이 투자 결정을 흐리게 만들어 잘못된 선택을 하게 할 수 있습니다.
#
# **감정 통제의 팁:**
#
# 1. **계획 세우기:** 미리 투자 계획을 세우고 목표를 설정하세요. 어떤 상황에도 이 계획을 유지하도록 노력하세요.
# 2. **분산 투자:** 여러 자산에 분산 투자하여 특정 종목이나 시장의 변동성에 덜 영향을 받도록 하세요.
# 3. **손실 수용:** 손실은 투자에서 자연스러운 부분입니다. 손실을 받더라도 감정적으로 대응하지 말고 냉정하게 판단하세요.
# 4. **정보 업데이트:** 시장과 기업의 상황을 꾸준히 모니터링하며 적절한 시점에 대응할 수 있는 능력을 기르세요.
# 5. **장기적 시각 유지:** 단기적인 변동성에 휘둘리지 않고 장기 목표에 집중하세요.
#
# 이러한 방법을 통해 감정을 통제하고 더욱 안정적인 투자 결정을 내릴 수 있습니다.
# 9, content:주식 투자에 관한 아홉 번째 팁은 "장기적인 관점으로 투자하라"입니다.短期적인 시장 변동성에 휘둘리지 않고, 기업의 기본적인 가치를 평가하여 장기적으로 성장할 것으로 예상되는 종목에 투자하세요.
#
# 장기 투자는 주식 시장의 변동성을 극복하고, 복리 효과를 통해 자산을 증대시킬 수 있는 좋은 방법입니다. 이를 위해 기업의 경영 상태, 산업 트렌드, 경제 전반의 흐름 등을 분석하고, 기초적인 재무 지표를 이해하는 것이 중요합니다.
#
# 주식 투자에서 일관된 전략을 유지하고, 정기적으로 투자 포트폴리오를 점검하며, 필요에 따라 조정을 하는 것도 잊지 마십시오.

# %% [markdown]
# # 토큰 사용량 확인

# %%
from langchain_community.callbacks import get_openai_callback

with get_openai_callback() as callback:
    message = [HumanMessage(content="서울 광장시장에서 가장 맛있는 길거리 음식은?")]
    response = llm.invoke(message)
    print(response.content)
    print(f"\n총 토큰: {callback.total_tokens}")
    print(f"프롬프트 토큰: {callback.prompt_tokens}")
    print(f"응답 토큰: {callback.completion_tokens}")
    print(f"비용(USD): ${callback.total_cost:.6f}")
# Out:
# 서울 광장시장에서 맛있는 길거리 음식으로는 다음과 같은 것들이 있습니다:
#
# 1. **떡볶이**: 매콤하고 달콤한 소스에 쫄깃한 떡이 어우러진 인기 있는 간식입니다.
# 2. **순대**: 돼지의 창자에 당면과 각종 재료를 채워 만든 순대는 오랜 전통의 길거리 음식입니다.
# 3. **튀김**: 오징어, 고구마, 야채 등을 튀겨서 바삭한 식감을 즐길 수 있습니다.
# 4. **핫바**: 다양한 재료를 반죽해 튀긴 핫바는 간편하면서도 맛있는 길거리 음식 중 하나입니다.
# 5. **김밥**: 여러 가지 재료가 들어가 있는 김밥은 간단하게 먹을 수 있어 인기가 많습니다.
# 6. **어묵**: 뜨끈한 국물과 함께 즐기는 어묵은 겨울철 특히 인기가 많습니다.
#
# 광장시장은 다양한 길거리 음식이 가득하니, 여러 가지를 시도해 보는 것도 좋습니다!
#
# 총 토큰: 273
# 프롬프트 토큰: 20
# 응답 토큰: 253
# 비용(USD): $0.000155

# %% [markdown]
# # 대화시작 / 후속질문 [삼성전자]

# %%
# 대화시작
from langchain_core.messages import SystemMessage, HumanMessage

messages = [
    SystemMessage(content="당신은 주식 투자 전문가로 고객의 투자 결정에 도움을 줍니다."),
    HumanMessage(content="삼성전자 주식을 지금 매수해도 될까요?")
]

response = llm.invoke(messages)
print(response.content)
# Out:
# 삼성전자의 주식을 매수할지 여부는 여러 가지 요소를 고려해야 합니다. 다음은 몇 가지 중요한 점입니다:
#
# 1. **재무 성과**: 삼성전자의 최근 실적, 매출 성장률, 이익률 등을 살펴보세요. 반도체, 스마트폰, 가전 등 주요 사업 부문의 성과가 중요합니다.
#
# 2. **시장 전망**: 반도체 산업은 cyclical한 특징을 가지고 있기 때문에 앞으로의 수요 및 공급 전망을 주의 깊게 확인하세요. 특히 AI, 5G, IoT 등의 기술 발전이 반도체 수요에 미치는 영향을 알아보세요.
#
# 3. **경쟁 상황**: 경쟁사와의 비교도 중요합니다. TSMC, 애플, 퀄컴 등과의 경쟁에서 삼성전자의 위치를 고려해야 합니다.
#
# 4. **경제 전반의 상황**: 금리, 인플레이션, 글로벌 경제 성장률 등이 주식 시장에 미치는 영향을 고려하세요.
#
# 5. **기술적 분석**: 주가 차트를 분석해 주요 지지선 및 저항선을 확인하고, 현재 가격이 적정한지 판단하는 것도 좋습니다.
#
# 이러한 요소들을 종합적으로 고려한 후, 본인의 투자 목표와 리스크 성향에 맞춰 매수 결정을 내리는 것이 중요합니다. 전문가의 조언을 듣거나 추가적인 자료를 참고하는 것도 도움이 될 수 있습니다.

# %%
# 후속질문
messages = messages + [response, HumanMessage(content="그렇다면 목표 주가는 얼마로 보시나요?")]

response2 = llm.invoke(messages)
print(response2.content)
# Out:
# 삼성전자의 목표 주가는 여러 요인에 따라 달라질 수 있으며, 정확한 숫자를 제시하기는 어렵습니다. 그러나 목표 주가를 설정할 때 고려해야 할 요소들에는 다음과 같은 것들이 있습니다.
#
# 1. **PE 비율 (주가수익비율)**: 삼성전자의 현재 PE 비율과 역사적 평균, 그리고 산업 평균을 비교하여 목표 주가를 계산할 수 있습니다.
#
# 2. **재무 지표**: EPS (주당순이익) 성장률을 바탕으로 목표 주가를 설정하는 방법도 있습니다. 예상 EPS에 적정 PE 비율을 곱하여 목표 주가를 도출할 수 있습니다.
#
# 3. **분석 기관의 리포트**: 여러 투자 은행이나 증권사의 애널리스트들이 제시하는 목표 주가를 참고할 수 있습니다. 그들은 시장 조사와 기업 실적을 바탕으로 목표 주가를 분석하고 있습니다.
#
# 4. **시장 전반의 상황**: 글로벌 경제 상황, 금리 변화, 환율 변동 등도 목표 주가에 영향을 미칩니다.
#
# 5. **수요와 공급**: 삼성전자의 주요 제품인 반도체 및 스마트폰 시장의 수요 전망도 고려해야 합니다.
#
# 현재의 시장 상황과 삼성전자의 미래 성장 가능성을 감안할 때 목표 주가는 다소 변동성이 클 수 있습니다. 일반적으로 애널리스트들은 삼성전자의 목표 주가를 예상할 때 $60-$80 (한화 약 70,000원~90,000원)의 범위에서 제시하는 경우가 많지만, 이는 시장의 변동과 기업의 성과에 따라 달라질 수 있습니다.
#
# 가장 정확한 정보는 최신 애널리스트 리포트나 시장 조사 자료를 참고하는 것이 좋습니다.

# %% [markdown]
# # messages 쌓아가기

# %%
messages = [
    SystemMessage(content="당신은 주식 투자 전문가로 고객의 투자 결정에 도움을 줍니다."),
    HumanMessage(content="삼성전자 주식을 지금 매수해도 될까요?")
]

response = llm.invoke(messages)
messages.append(response)  # AI 응답을 히스토리에 추가
messages
# Out:
# [SystemMessage(content='당신은 주식 투자 전문가로 고객의 투자 결정에 도움을 줍니다.', additional_kwargs={}, response_metadata={}),
#  HumanMessage(content='삼성전자 주식을 지금 매수해도 될까요?', additional_kwargs={}, response_metadata={}),
#  AIMessage(content='삼성전자 주식을 매수할지 여부를 결정하기 위해 여러 가지 요소를 고려해야 합니다.\n\n1. **기본적 분석**: 삼성전자의 최근 실적, 매출 성장, 순이익 등을 검토하세요. 최근 분기 실적이 긍정적인지, 그리고 장기적으로 안정적인 성장 가능성을 가지고 있는지 확인해야 합니다.\n\n2. **시장 환경**: 현재 반도체 산업과 기술 산업 전반에 대한 전망을 살펴보세요. 글로벌 경제 상황, 수요 공급 동향, 경쟁사 상황 등이 중요합니다.\n\n3. **기술적 분석**: 주가 차트를 분석하여 매수 시점을 판단할 수 있습니다. 지원선, 저항선, 이동 평균선 등을 고려해 기술적 신호를 분석하세요.\n\n4. **투자 목표**: 개인의 투자 성향과 목표에 따라 결정해야 합니다. 단기 투자인지, 장기 투자인지 명확히 해야 하며, 이에 따라 전략이 달라집니다.\n\n5. **리스크 관리**: 주식 투자에는 항상 리스크가 따릅니다. 손실을 감당할 수 있는지, 포트폴리오 내에서의 비중은 적절한지 검토해보세요.\n\n결론적으로, 삼성전자 주식을 지금 매수할지 여부는 위의 요소를 종합적으로 고려한 후에 결정하는 것이 좋습니다. 추가적인 정보나 특정 질문이 있으시다면 더 도와드리겠습니다.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 312, 'prompt_tokens': 43, 'total_tokens': 355, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_3743ed1177', 'id': 'chatcmpl-DSDRFo5l9qzai9YRBQu4hp6lJjqVW', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019d6b08-76e3-72b1-8591-08862ec48991-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 43, 'output_tokens': 312, 'total_tokens': 355, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]

# %%
# 후속 질문 (이전 맥락 유지)
messages.append(HumanMessage(content="그렇다면 목표 주가는 얼마로 보시나요?"))

# %%
messages
# Out:
# [SystemMessage(content='당신은 주식 투자 전문가로 고객의 투자 결정에 도움을 줍니다.', additional_kwargs={}, response_metadata={}),
#  HumanMessage(content='삼성전자 주식을 지금 매수해도 될까요?', additional_kwargs={}, response_metadata={}),
#  AIMessage(content='삼성전자 주식을 매수할지 여부를 결정하기 위해 여러 가지 요소를 고려해야 합니다.\n\n1. **기본적 분석**: 삼성전자의 최근 실적, 매출 성장, 순이익 등을 검토하세요. 최근 분기 실적이 긍정적인지, 그리고 장기적으로 안정적인 성장 가능성을 가지고 있는지 확인해야 합니다.\n\n2. **시장 환경**: 현재 반도체 산업과 기술 산업 전반에 대한 전망을 살펴보세요. 글로벌 경제 상황, 수요 공급 동향, 경쟁사 상황 등이 중요합니다.\n\n3. **기술적 분석**: 주가 차트를 분석하여 매수 시점을 판단할 수 있습니다. 지원선, 저항선, 이동 평균선 등을 고려해 기술적 신호를 분석하세요.\n\n4. **투자 목표**: 개인의 투자 성향과 목표에 따라 결정해야 합니다. 단기 투자인지, 장기 투자인지 명확히 해야 하며, 이에 따라 전략이 달라집니다.\n\n5. **리스크 관리**: 주식 투자에는 항상 리스크가 따릅니다. 손실을 감당할 수 있는지, 포트폴리오 내에서의 비중은 적절한지 검토해보세요.\n\n결론적으로, 삼성전자 주식을 지금 매수할지 여부는 위의 요소를 종합적으로 고려한 후에 결정하는 것이 좋습니다. 추가적인 정보나 특정 질문이 있으시다면 더 도와드리겠습니다.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 312, 'prompt_tokens': 43, 'total_tokens': 355, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_3743ed1177', 'id': 'chatcmpl-DSDRFo5l9qzai9YRBQu4hp6lJjqVW', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019d6b08-76e3-72b1-8591-08862ec48991-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 43, 'output_tokens': 312, 'total_tokens': 355, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}),
#  HumanMessage(content='그렇다면 목표 주가는 얼마로 보시나요?', additional_kwargs={}, response_metadata={})]

# %%
response = llm.invoke(messages)
response
# Out:
# AIMessage(content='삼성전자의 목표 주가는 다양한 요소에 따라 달라질 수 있습니다. 목표 주가를 설정할 때 고려해야 할 주요 요소는 다음과 같습니다.\n\n1. **재무 실적**: 삼성전자의 최근 실적, 성장률, 이익 전망 등을 기반으로 목표 주가를 설정할 수 있습니다. 예를 들어, 매출 성장률과 순이익률을 바탕으로 예측할 수 있습니다.\n\n2. **산업 전망**: 반도체 시장, 디스플레이, 모바일 기기 및 기타 분야의 성장 전망에 따라 목표 주가가 달라질 수 있습니다. 최근 반도체 수요 변화나 글로벌 경제 상황이 얼마나 영향을 미칠지도 고민해야 합니다.\n\n3. **경쟁 상황**: 주요 경쟁사들의 동향과 시장 점유율 변화, 기술 혁신 등을 고려하여 삼성전자의 상대적인 위치를 평가해야 합니다.\n\n4. **테크니컬 지표**: 기술적 분석을 통해 저항선과 지지선을 고려한 목표 주가 설정도 가능합니다.\n\n각 투자 전문가들이 사용하는 모델이나 방법론에 따라 목표 주가는 각기 다를 수 있으며, 주식 시장의 변동성 때문에 반드시 변동이 생길 수 있습니다. 일반적으로 애널리스트들은 기업의 재무 현황과 시장 환경을 바탕으로 목표 주가를 제시합니다.\n\n정확한 목표 주가는 현재의 시장 상황과 전문가들의 의견을 종합적으로 참고하여 결정하는 것이 좋습니다. 삼성전자의 경우, 글로벌 금융 분석 플랫폼이나 전문가 의견을 참고하여 구체적인 목표 주가를 파악할 수 있습니다.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 341, 'prompt_tokens': 377, 'total_tokens': 718, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_87ea66f7b4', 'id': 'chatcmpl-DSDV8XDbaOgwU5eFsj7aCKh44m8QD', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019d6b0c-2482-7310-9655-d86f8b77641a-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 377, 'output_tokens': 341, 'total_tokens': 718, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})

# %%
messages.append(response)
messages
# Out:
# [SystemMessage(content='당신은 주식 투자 전문가로 고객의 투자 결정에 도움을 줍니다.', additional_kwargs={}, response_metadata={}),
#  HumanMessage(content='삼성전자 주식을 지금 매수해도 될까요?', additional_kwargs={}, response_metadata={}),
#  AIMessage(content='삼성전자 주식을 매수할지 여부를 결정하기 위해 여러 가지 요소를 고려해야 합니다.\n\n1. **기본적 분석**: 삼성전자의 최근 실적, 매출 성장, 순이익 등을 검토하세요. 최근 분기 실적이 긍정적인지, 그리고 장기적으로 안정적인 성장 가능성을 가지고 있는지 확인해야 합니다.\n\n2. **시장 환경**: 현재 반도체 산업과 기술 산업 전반에 대한 전망을 살펴보세요. 글로벌 경제 상황, 수요 공급 동향, 경쟁사 상황 등이 중요합니다.\n\n3. **기술적 분석**: 주가 차트를 분석하여 매수 시점을 판단할 수 있습니다. 지원선, 저항선, 이동 평균선 등을 고려해 기술적 신호를 분석하세요.\n\n4. **투자 목표**: 개인의 투자 성향과 목표에 따라 결정해야 합니다. 단기 투자인지, 장기 투자인지 명확히 해야 하며, 이에 따라 전략이 달라집니다.\n\n5. **리스크 관리**: 주식 투자에는 항상 리스크가 따릅니다. 손실을 감당할 수 있는지, 포트폴리오 내에서의 비중은 적절한지 검토해보세요.\n\n결론적으로, 삼성전자 주식을 지금 매수할지 여부는 위의 요소를 종합적으로 고려한 후에 결정하는 것이 좋습니다. 추가적인 정보나 특정 질문이 있으시다면 더 도와드리겠습니다.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 312, 'prompt_tokens': 43, 'total_tokens': 355, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_3743ed1177', 'id': 'chatcmpl-DSDRFo5l9qzai9YRBQu4hp6lJjqVW', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019d6b08-76e3-72b1-8591-08862ec48991-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 43, 'output_tokens': 312, 'total_tokens': 355, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}),
#  HumanMessage(content='그렇다면 목표 주가는 얼마로 보시나요?', additional_kwargs={}, response_metadata={}),
#  AIMessage(content='삼성전자의 목표 주가는 다양한 요소에 따라 달라질 수 있습니다. 목표 주가를 설정할 때 고려해야 할 주요 요소는 다음과 같습니다.\n\n1. **재무 실적**: 삼성전자의 최근 실적, 성장률, 이익 전망 등을 기반으로 목표 주가를 설정할 수 있습니다. 예를 들어, 매출 성장률과 순이익률을 바탕으로 예측할 수 있습니다.\n\n2. **산업 전망**: 반도체 시장, 디스플레이, 모바일 기기 및 기타 분야의 성장 전망에 따라 목표 주가가 달라질 수 있습니다. 최근 반도체 수요 변화나 글로벌 경제 상황이 얼마나 영향을 미칠지도 고민해야 합니다.\n\n3. **경쟁 상황**: 주요 경쟁사들의 동향과 시장 점유율 변화, 기술 혁신 등을 고려하여 삼성전자의 상대적인 위치를 평가해야 합니다.\n\n4. **테크니컬 지표**: 기술적 분석을 통해 저항선과 지지선을 고려한 목표 주가 설정도 가능합니다.\n\n각 투자 전문가들이 사용하는 모델이나 방법론에 따라 목표 주가는 각기 다를 수 있으며, 주식 시장의 변동성 때문에 반드시 변동이 생길 수 있습니다. 일반적으로 애널리스트들은 기업의 재무 현황과 시장 환경을 바탕으로 목표 주가를 제시합니다.\n\n정확한 목표 주가는 현재의 시장 상황과 전문가들의 의견을 종합적으로 참고하여 결정하는 것이 좋습니다. 삼성전자의 경우, 글로벌 금융 분석 플랫폼이나 전문가 의견을 참고하여 구체적인 목표 주가를 파악할 수 있습니다.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 341, 'prompt_tokens': 377, 'total_tokens': 718, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_87ea66f7b4', 'id': 'chatcmpl-DSDV8XDbaOgwU5eFsj7aCKh44m8QD', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019d6b0c-2482-7310-9655-d86f8b77641a-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 377, 'output_tokens': 341, 'total_tokens': 718, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]

# %% [markdown]
# # travel 주제

# %%
travel_messages = [
  SystemMessage(content="당신은 여행 전문가로 고객의 여행 일정에 도움을 줍니다."),
  HumanMessage(content="부산 여행에서 딱 한 곳만을 가봐야 한다면 어떤 곳인지 알려주세요.")
]

# %%
HumanMessage(content="부산역에서 그곳에 가는 교통편을 알려주세요.")
HumanMessage(content="그 근처에 먹을 만한 음식점들을 추천해주세요.")
# Out:
# HumanMessage(content='그 근처에 먹을 만한 음식점들을 추천해주세요.', additional_kwargs={}, response_metadata={})

# %%
# 대화시작
travel_messages = [
  SystemMessage(content="당신은 여행 전문가로 고객의 여행 일정에 도움을 줍니다."),
  HumanMessage(content="부산 여행에서 딱 한 곳만을 가봐야 한다면 어떤 곳인지 알려주세요.")
]

response = llm.invoke(travel_messages)
travel_messages.append(response)
print(response.content)
# Out:
# 부산 여행에서 딱 한 곳만을 가봐야 한다면, **해운대**를 추천합니다. 해운대는 아름다운 해변과 함께 다양한 레스토랑, 카페, 상점이 밀집해 있어 부산의 매력을 잘 느낄 수 있는 지역입니다. 특히 해운대 해수욕장은 넓고 깨끗한 백사장이 매력적이며, 여름철에는 많은 관광객이 찾는 인기 장소입니다. 또한, 인근의 동백섬, APEC 나루공원, 그리고 마린시티의 야경도 놓치기 아쉬운 포인트입니다. 해운대에서 부산의 해양 문화를 만끽해 보세요!

# %%
# 후속질문 1
travel_messages.append(HumanMessage(content="부산역에서 그곳에 가는 교통편을 알려주세요."))

response = llm.invoke(travel_messages)
travel_messages.append(response)
print(response.content)
# Out:
# 부산역에서 해운대로 가는 교통편은 여러 가지가 있습니다. 가장 편리한 방법은 다음과 같습니다:
#
# 1. **지하철 이용하기**:
#    - 부산역에서 **부산 지하철 1호선**에 탑승합니다.
#    - **서면역**에서 갈아타고, **부산 지하철 2호선**으로 환승합니다.
#    - **해운대역**에서 하차하면 됩니다. 해운대역 3번 출구로 나가면 해운드 해수욕장까지 도보로 이동할 수 있습니다. 전체 소요 시간은 약 40분 정도입니다.
#
# 2. **버스 이용하기**:
#    - 부산역 앞 버스 정류장에서 **성지병원 방향**으로 가는 **1003번** 또는 **1004번** 버스를 탑승합니다.
#    - 해운대 해수욕장에 있는 정류장에서 하차하면 됩니다. 소요 시간은 약 50분에서 1시간 정도 소요됩니다.
#
# 3. **택시 이용하기**:
#    - 부산역에서 택시를 타면 해운대까지 약 30분 정도 소요됩니다. 요금은 교통 상황에 따라 달라질 수 있지만, 대략 15,000원에서 20,000원 정도 예상하면 됩니다.
#
# 편리한 교통편을 선택하여 해운대에서 즐거운 시간을 보내세요!

# %%
# 후속질문 2
travel_messages.append(HumanMessage(content="그 근처에 먹을 만한 음식점들을 추천해주세요."))

response = llm.invoke(travel_messages)
travel_messages.append(response)
print(response.content)
# Out:
# 해운대 근처에는 맛있는 음식점이 많습니다. 몇 가지 추천할 만한 곳을 소개합니다:
#
# 1. **해운대 암소갈비**
#    - 유명한 한우 갈비 전문점으로, 질 좋은 고기를 저렴한 가격에 즐길 수 있습니다. 갈비를 구워서 싸먹는 경험이 일품입니다.
#
# 2. **부산참치**
#    - 신선한 참치 sashimi와 초밥을 전문으로 하는 곳입니다. 신선한 해산물을 즐기고 싶다면 이곳을 추천합니다.
#
# 3. **동백섬 해물탕**
#    - 해운대 바다의 신선한 해산물을 사용한 해물탕과 매운탕이 유명한 집입니다. 다양한 해산물과 깊은 국물 맛이 일품입니다.
#
# 4. **해운대 밀면**
#    - 부산의 전통 음식 중 하나인 밀면을 맛볼 수 있는 집입니다. 시원한 육수와 쫄깃한 면발이 매력이죠.
#
# 5. **수영만 요트하우스 커피 & 조식**
#    - 해운대 근처에서 바다를 바라보며 조식을 즐길 수 있는 카페입니다. 브런치 메뉴와 커피가 훌륭합니다.
#
# 6. **이바돔감자탕**
#    - 깊고 진한 국물의 감자탕으로 유명합니다. 해운대 지역에서 인기가 많은 곳입니다.
#
# 이 외에도 해운대 주변에는 다양한 카페와 레스토랑이 많으므로, 분위기와 취향에 맞는 곳을 선택해 보세요. 맛있는 식사와 함께 해운대의 멋진 경치도 즐기시길 바랍니다!

# %%
# 후속질문3
travel_messages.append(HumanMessage(content="하루 일정으로 코스를 짜주세요. 예산은 5만원입니다."))

response = llm.invoke(travel_messages)
travel_messages.append(response)
print(response.content)
# Out:
# 부산 해운대에서의 하루 일정을 5만원 예산으로 구성해 보겠습니다.
#
# ### 해운대 하루 코스
#
# #### 오전
# 1. **해운대 해수욕장 산책 (무료)**
#    - 아침 일찍 해운대 해수욕장에서 산책하며 바다의 경치를 즐기세요. 파도 소리와 함께 상쾌한 공기가 기분을 좋게 해줄 것입니다.
#
# 2. **해운대 조식 (약 8,000원)**
#    - 근처에 위치한 브런치 카페에서 조식을 즐기세요. 예를 들어, '해운대 밀면'에서 밀면을 시키면 약 8,000원 정도입니다.
#
# #### 오후
# 3. **동백섬 탐방 (무료)**
#    - 해운대에서 동백섬으로 가는 산책로를 따라 걸으며 아름다운 바다와 경치를 감상하세요. 동백섬의 전망대와 사랑의 출발점에서 사진도 찍어보세요.
#
# 4. **점심식사 (약 10,000원)**
#    - 근처의 '해운대 암소갈비' 또는 '수영만 요트하우스'에서 한 끼를 해결합니다. 세트 메뉴나 단품으로도 알차게 시킬 수 있습니다. 예산은 약 10,000원으로 잡습니다.
#
# 5. **해운대시장 둘러보기 (무료 / 간식 소소한 비용 고려)**
#    - 해운대시장에서 다양한 먹거리와 기념품을 구경하세요. 여유가 있다면 전통 간식을 소소히 구매하는 것도 좋습니다. (예: 오뎅, 떡볶이 등 약 5,000원)
#
# #### 저녁
# 6. **부산 탐방 또는 바닷가에서 저녁노을 감상 (무료)**
#    - 해운대 바다 근처에서 저녁노을을 감상하세요. 여유로운 시간을 갖고, 밤바다의 낭만을 느껴보세요.
#
# 7. **저녁식사 (약 10,000원)**
#    - '부산참치'에서 참치회를 시켜 보세요. 가격대에 따라 약 10,000원 정도의 메뉴를 선택할 수 있습니다.
#
# #### 기타
# - **교통비 (약 5,000원)**
#    - 부산역에서 해운대로 이동할 때 지하철이나 버스를 이용할 경우 왕복으로 대략 5,000원 정도 예상합니다.
#
# ### 총 비용 요약
# - 조식: 8,000원
# - 점심: 10,000원
# - 간식: 5,000원
# - 저녁: 10,000원
# - 교통비: 5,000원
# - **총합: 38,000원**
#
# 이 일정을 통해 해운대의 매력을 만끽하며 여유로운 하루를 보낼 수 있습니다. 예산을 조금 더 유연하게 사용할 수 있으니, 취향에 따라 조절하실 수 있습니다!

# %%
# 대화 히스토리 확인
for msg in travel_messages:
    print(f"[{msg.__class__.__name__}] {msg.content[:80]}")
# Out:
# [SystemMessage] 당신은 여행 전문가로 고객의 여행 일정에 도움을 줍니다.
# [HumanMessage] 부산 여행에서 딱 한 곳만을 가봐야 한다면 어떤 곳인지 알려주세요.
# [AIMessage] 부산 여행에서 딱 한 곳만을 가봐야 한다면, **해운대**를 추천합니다. 해운대는 아름다운 해변과 함께 다양한 레스토랑, 카페, 상점이 밀집해
# [HumanMessage] 부산역에서 그곳에 가는 교통편을 알려주세요.
# [AIMessage] 부산역에서 해운대로 가는 교통편은 여러 가지가 있습니다. 가장 편리한 방법은 다음과 같습니다:
#
# 1. **지하철 이용하기**:
#    - 부산역에
# [HumanMessage] 그 근처에 먹을 만한 음식점들을 추천해주세요.
# [AIMessage] 해운대 근처에는 맛있는 음식점이 많습니다. 몇 가지 추천할 만한 곳을 소개합니다:
#
# 1. **해운대 암소갈비**
#    - 유명한 한우 갈비 전문
# [HumanMessage] 하루 일정으로 코스를 짜주세요. 예산은 5만원입니다.
# [AIMessage] 부산 해운대에서의 하루 일정을 5만원 예산으로 구성해 보겠습니다.
#
# ### 해운대 하루 코스
#
# #### 오전
# 1. **해운대 해수욕장 산책 (

# %% [markdown]
# # 토큰 사용량 확인

# %%
from langchain_community.callbacks import get_openai_callback

with get_openai_callback() as callback:
    travel_messages = [
        SystemMessage(content="당신은 여행 전문가로 고객의 여행 일정에 도움을 줍니다."),
        HumanMessage(content="부산 여행에서 딱 한 곳만을 가봐야 한다면 어떤 곳인지 알려주세요.")
    ]
    response = llm.invoke(travel_messages)
    travel_messages.append(response)
    print("[1] 대화 시작")
    print(response.content[:80], "...\n")

    travel_messages.append(HumanMessage(content="부산역에서 그곳에 가는 교통편을 알려주세요."))
    response = llm.invoke(travel_messages)
    travel_messages.append(response)
    print("[2] 후속 질문 1")
    print(response.content[:80], "...\n")

    travel_messages.append(HumanMessage(content="그 근처에 먹을 만한 음식점들을 추천해주세요."))
    response = llm.invoke(travel_messages)
    travel_messages.append(response)
    print("[3] 후속 질문 2")
    print(response.content[:80], "...\n")

    travel_messages.append(HumanMessage(content="하루 일정으로 코스를 짜주세요. 예산은 5만원입니다."))
    response = llm.invoke(travel_messages)
    travel_messages.append(response)
    print("[4] 후속 질문 3")
    print(response.content[:80], "...\n")

    print("=" * 50)
    print(f"총 토큰: {callback.total_tokens}")
    print(f"프롬프트 토큰: {callback.prompt_tokens}")
    print(f"응답 토큰: {callback.completion_tokens}")
    print(f"비용(USD): ${callback.total_cost:.6f}")
# Out:
# [1] 대화 시작
# 부산 여행에서 딱 한 곳만을 선택해야 한다면, **해운대 해수욕장**을 추천합니다. 해운대는 부산의 상징적인 해변으로, 아름다운 바다 풍경과 다 ...
#
# [2] 후속 질문 1
# 부산역에서 해운대 해수욕장까지 가는 교통편은 여러 가지가 있습니다. 가장 일반적인 방법은 다음과 같습니다:
#
# 1. **지하철 이용**:
#    - ...
#
# [3] 후속 질문 2
# 해운대 해수욕장 근처에는 다양한 맛집이 많아 여러 가지 음식을 즐길 수 있습니다. 몇 가지 추천해드릴게요:
#
# 1. **해운대 물회**:
#    - ...
#
# [4] 후속 질문 3
# 부산에서 하루를 보내는 코스와 예산을 고려하여 일정을 짜드리겠습니다. 해운대를 중심으로 다양한 체험과 음식을 즐길 수 있는 코스를 구성해보았습니 ...
#
# ==================================================
# 총 토큰: 3253
# 프롬프트 토큰: 1831
# 응답 토큰: 1422
# 비용(USD): $0.001128

# %% [markdown]
# # travel

# %%
from langchain_community.callbacks.manager import get_openai_callback
from langchain_core.messages import SystemMessage, HumanMessage

# 1. 메시지 구성
travel_messages = [
    SystemMessage(content='당신은 여행 전문가로 고객의 여행 일정에 도움을 줍니다.'),
    HumanMessage(content='부산 여행에서 딱 한 곳만을 가봐야 한다면 어떤 곳인지 알려주세요.')
]

# 2. 콜백을 사용하여 토큰 및 비용 추적
with get_openai_callback() as cb:
    response_travel = llm.invoke(travel_messages)
    
    # 결과 출력
    print(f"답변: {response_travel.content}")
    print("-" * 30)
    
    # 토큰 정보 출력
    print(f"총 사용 토큰: {cb.total_tokens}")
    print(f"프롬프트 토큰: {cb.prompt_tokens}")
    print(f"응답 토큰: {cb.completion_tokens}")
    print(f"예상 비용: ${cb.total_cost:.6f}")
# Out:
# 답변: 부산 여행에서 단 한 곳을 선택해야 한다면, **해운대 해수욕장**을 추천합니다. 해운대는 부산을 대표하는 아름다운 해변으로, 맑은 바다와 환상적인 경치를 감상할 수 있습니다. 여름철에는 많은 사람들이 수영과 일광욕을 즐기고, 주변에는 다양한 식당과 카페, 상점들이 있어 먹거리와 쇼핑도 함께 즐길 수 있습니다. 또한, 해운대 근처에는 동백섬, 아난티 코브, 해운대 마리나 등 볼거리가 많아 부산의 매력을 만끽하기에 최적의 장소입니다.
# ------------------------------
# 총 사용 토큰: 194
# 프롬프트 토큰: 49
# 응답 토큰: 145
# 예상 비용: $0.000094

# %% [markdown]
# # 랭체인의 대화 히스토리 관리 객체 사용하기

# %%
from langchain_openai import ChatOpenAI
from langchain_core.prompts import ChatPromptTemplate, MessagesPlaceholder
from langchain_core.runnables.history import RunnableWithMessageHistory
from langchain_community.chat_message_histories import ChatMessageHistory

llm = ChatOpenAI(model="gpt-4o-mini")

prompt = ChatPromptTemplate.from_messages([
    ("system", "당신은 주식 투자 전문가입니다."),
    MessagesPlaceholder(variable_name="history"),
    ("human", "{input}")
])

chain = prompt | llm

# %%
# 실행 위해선 (1,2,3)필요, 체인준비까지.
# 세션별 히스토리 저장소(1)
store = {}
#함수(2)
def get_session_history(session_id: str):
    if session_id not in store:
        store[session_id] = ChatMessageHistory()
    return store[session_id]
#runnable chain(object)(3)
chain_with_history = RunnableWithMessageHistory(
    chain,
    get_session_history,
    input_messages_key="input",
    history_messages_key="history"
)

# %%
# 첫 번째 질문 (runnable chain)
response = chain_with_history.invoke(
    {"input": "삼성전자 주식을 지금 매수해도 될까요?"},
    config={"configurable": {"session_id": "user_001"}}
)
print(response.content)
# Out:
# 삼성전자 주식을 매수할지 여부는 여러 요소를 고려해야 합니다. 다음 몇 가지를 참고하시기 바랍니다:
#
# 1. **재무상태 및 실적**: 삼성전자의 최근 실적과 재무제표를 분석하여 수익성, 부채 수준, 현금 흐름 등을 점검해 보세요. 안정적인 실적을 유지하고 있는지 확인하는 것이 중요합니다.
#
# 2. **산업 전망**: 반도체, 스마트폰, 가전 등 삼성전자가 주요 사업으로 하고 있는 산업의 전망이 긍정적인지 살펴보세요. 특히 반도체 시장은 수요와 공급, 기술 발전 등에 민감합니다.
#
# 3. **주가 평가**: 현재 주가가 과대평가되었는지, 과소평가되었는지를 판단하기 위해 주식의 PER(주가수익비율), PBR(주가순자산비율) 등의 지표를 참고하세요.
#
# 4. **시장 동향**: 글로벌 경제 상황, 환율 변동, 경쟁사 동향 등 외부 변수들도 고려해야 합니다. 국내외 경제 지표나 정책 변화가 주가에 미치는 영향을 주의 깊게 살펴보세요.
#
# 5. **장기 투자 vs 단기 투자**: 투자 목표가 장기적인 안정성을 원하는 것인지 아니면 단기적인 수익을 노리는 것인지에 따라 접근 방식이 달라질 수 있습니다.
#
# 결론적으로, 삼성전자 주식 매수 여부는 개인의 투자 성향, 리스크 감내 수준, 시장 상황을 종합적으로 고려한 후 결정하는 것이 좋습니다. 전문가의 조언을 듣고, 충분한 시장 조사를 한 후 투자 결정을 내리는 것이 중요합니다.

# %%
# 두 번째 질문 (runnable chain), session_id:'user_001'이라서 맥락유지 -> 목표주가:삼성
response = chain_with_history.invoke(
    {"input": "그렇다면 목표 주가는 얼마로 보시나요?"},
    config={"configurable": {"session_id": "user_001"}}
)
print(response.content)
# Out:
# 삼성전자의 목표 주가는 여러 요소에 따라 달라지며, 금융 전문가들이 사용하는 여러 모델에 따라 다르게 산출될 수 있습니다. 이를 평가하기 위해서는 다음과 같은 요소를 고려해야 합니다:
#
# 1. **재무제표 분석**: 매출 성장률, 이익 성장률, 자산 구성, 부채 비율 등을 분석하여 회사의 가치를 산출합니다.
#
# 2. **업계 전망**: 반도체, 모바일, 가전 분야에서의 시장 전망과 경쟁 업체의 동향을 감안하여 성장 가능성을 평가합니다.
#
# 3. **투자자 감정**: 시장의 투자 심리와 주식에 대한 수요와 공급 영향을 고려합니다.
#
# 4. **주가 계산 방식**: PER, PBR, DCF(할인 현금 흐름 분석) 등의 방법을 통해 목표 주가를 산출합니다.
#
# 현재 시점에서 삼성전자의 목표 주가는 전문가의 의견과 금융 데이터 제공 업체의 분석에 따라 다를 수 있습니다. 예를 들어, 최근의 시세와 매출 성장 기대치를 반영하여 목표 주가를 제시하는 투자기관들이 있으므로 그런 의견을 참고하는 것이 좋습니다.
#
# 정확한 목표 주가를 제시하는 것은 어렵지만, 독립적인 분석 및 전문가 의견을 통해 최근의 목표 주가 범위를 파악하는 것이 중요합니다. 최신 보고서와 분석 자료를 찾아보시는 것을 추천드립니다.

# %%
# 세 번째 질문 (runnable chain)
response = chain_with_history.invoke(
    {"input": "그렇다면, 주가의 위험요소는 무엇인가요?"},
    config={"configurable": {"session_id": "user_001"}}
)
print(response.content)
# Out:
# 삼성전자 주가에 영향을 미칠 수 있는 위험 요소는 여러 가지가 있습니다. 주식 투자에서 위험 요소를 파악하는 것은 매우 중요합니다. 다음은 삼성전자의 주가에 영향을 미칠 수 있는 주요 위험 요소들입니다:
#
# 1. **글로벌 경제 상황**: 세계 경제의 불확실성이 삼성전자의 실적에 부정적인 영향을 미칠 수 있습니다. 경제 침체나 무역 전쟁 등은 소비자 수요에 영향을 주고, 이는 삼성전자의 매출에 타격을 줄 수 있습니다.
#
# 2. **반도체 시장 변동성**: 삼성전자의 주요 사업은 반도체이며, 반도체 시장은 수요와 공급에 민감합니다. 가격 하락이나 수요 감소는 수익성에 큰 영향을 미칠 수 있습니다.
#
# 3. **경쟁 심화**: 다른 반도체 제조업체나 스마트폰 제조사들과의 경쟁이 치열해지면 시장 점유율이 감소할 위험이 있습니다. 특히 중국 기업들이 상당한 성장을 하고 있으므로 주의가 필요합니다.
#
# 4. **기술 변화와 혁신**: 기술 변화에 적절히 대응하지 못할 경우 경쟁에서 뒤처질 수 있습니다. 예를 들어, AI, IoT, 5G 등 새로운 기술이 시장에서 주목받고 있는 상황에서 빠르게 적응하지 못할 위험이 있습니다.
#
# 5. **정치적 및 규제적 위험**: 국내외 정치적 불안정이나 규제 변경도 주가에 큰 영향을 미칠 수 있습니다. 예를 들어, 미국과 중국 간의 갈등, 반독점 규제, 수출 통제 등은 기업 운영에 리스크를 추가합니다.
#
# 6. **환율 변동**: 삼성전자는 해외 매출이 많기 때문에 환율 변동이 수익성에 영향을 미칠 수 있습니다. 특히 원화와 달러화의 환율 변동이 주요 변수로 작용할 수 있습니다.
#
# 7. **자연재해 및 기타 비상사태**: 공급망에 영향을 주는 자연재해나 팬데믹과 같은 비상사태도 비즈니스에 큰 영향을 미칠 수 있습니다.
#
# 이와 같은 위험 요소들을 충분히 이해하고 고려한 후 투자 결정을 내리는 것이 중요합니다. 각자의 투자 성향에 맞춰 리스크를 관리하는 전략을 세우는 것이 필요합니다.

# %%
# 세 번째 질문 (runnable chain), 다른 session_id ->일반적인 주가에 대한 답변
response = chain_with_history.invoke(
    {"input": "그렇다면, 주가의 위험요소는 무엇인가요?"},
    config={"configurable": {"session_id": "user_002"}}
)
print(response.content)
# Out:
# 주가의 위험 요소는 여러 가지가 있으며, 일반적으로 넷째와 같은 범주로 나눌 수 있습니다.
#
# 1. **시장 위험 (Market Risk)**:
#    - 전체 시장의 움직임에 의해 영향을 받습니다. 예를 들어, 경제 성장, 금리 상승, 정치적 불안 등은 모든 주식에 영향을 미칠 수 있습니다.
#
# 2. **산업 위험 (Industry Risk)**:
#    - 특정 산업에 대한 위험요소로, 기술 변화, 소비자 선호 변화, 경쟁 심화 등이 포함됩니다. 예를 들어, 전통적인 자동차 산업과 전기차 산업의 경쟁이 심화될 경우 관련 기업의 주가에 영향을 미칠 수 있습니다.
#
# 3. **개별 회사 위험 (Company-Specific Risk)**:
#    - 각 기업의 재무 상태나 경영 전략에 따라 달라지는 위험입니다. 예를 들어, 분기 실적 발표에서 예상보다 저조한 실적을 기록할 경우 주가에 큰 영향을 미칠 수 있습니다.
#
# 4. **유동성 위험 (Liquidity Risk)**:
#    - 자산을 원하는 가격으로 즉시 매도하기 어려운 경우 발생하는 위험입니다. 거래량이 적은 주식은 가격 변동이 클 수 있으며, 시장에서 쉽게 거래되지 않을 수도 있습니다.
#
# 5. **법적 및 규제 위험 (Legal and Regulatory Risk)**:
#    - 법적 문제나 새로운 규제가 기업에 부정적인 영향을 미칠 경우 발생하는 위험입니다. 예를 들어, 환경 규제가 강화되면 일부 산업의 수익성이 저하될 수 있습니다.
#
# 이 외에도 다양한 요인들이 주가에 영향을 미칠 수 있으며, 투자자는 이러한 요소들을 종합적으로 고려해야 합니다.

# %% [markdown]
# # End
