# %%
import os
print(os.getcwd())
# Out:
# c:\Users\Admin\hipython\ml\energy_app

# %%
import os
# test_data 폴더가 있는지, 뭐가 들어있는지 확인
print(os.path.exists('./test_data'))
print(os.listdir('./test_data') if os.path.exists('./test_data') else "폴더 없음")
# Out:
# True
# ['compare_sets_2021-03-24.csv', 'result_db_2021-03-24.csv', 'result_Mixed_2021-03-24.csv', 'result_Set_A_2021-03-24.csv', 'result_Set_B_2021-03-24.csv', 'result_Set_C_2021-03-24.csv', 'test_input_mixed.csv', 'test_input_SetA.csv', 'test_input_SetB.csv', 'test_input_SetC.csv']

# %%
import pandas as pd
df = pd.read_csv('./test_data/result_Mixed_2021-03-24.csv', encoding='utf-8-sig')
df
# Out:
#           Date  hour  temperature  humidity  windspeed  rainfall  op_code  \
# 0   2021-03-24     0          NaN       NaN        NaN       NaN      NaN
# 1   2021-03-24     1          NaN       NaN        NaN       NaN      NaN
# 2   2021-03-24     2          NaN       NaN        NaN       NaN      NaN
# 3   2021-03-24     3          NaN       NaN        NaN       NaN      NaN
# 4   2021-03-24     4          NaN       NaN        NaN       NaN      NaN
# 5   2021-03-24     5          NaN       NaN        NaN       NaN      NaN
# 6   2021-03-24     6          NaN       NaN        NaN       NaN      NaN
# 7   2021-03-24     7          NaN       NaN        NaN       NaN      NaN
# 8   2021-03-24     8         12.3      51.5        2.0       0.0      NaN
# 9   2021-03-24     9         14.1      49.9        1.9       0.0      NaN
# 10  2021-03-24    10         15.7      48.0        1.2       0.0      NaN
# 11  2021-03-24    11         16.5      46.1        1.9       0.0      NaN
# ...

# %%
import pandas as pd

df = pd.read_csv('./test_data/result_Mixed_2021-03-24.csv', encoding='utf-8-sig')
df
# Out:
#           Date  hour  temperature  humidity  windspeed  rainfall  op_code  \
# 0   2021-03-24     0          NaN       NaN        NaN       NaN      NaN
# 1   2021-03-24     1          NaN       NaN        NaN       NaN      NaN
# 2   2021-03-24     2          NaN       NaN        NaN       NaN      NaN
# 3   2021-03-24     3          NaN       NaN        NaN       NaN      NaN
# 4   2021-03-24     4          NaN       NaN        NaN       NaN      NaN
# 5   2021-03-24     5          NaN       NaN        NaN       NaN      NaN
# 6   2021-03-24     6          NaN       NaN        NaN       NaN      NaN
# 7   2021-03-24     7          NaN       NaN        NaN       NaN      NaN
# 8   2021-03-24     8         12.3      51.5        2.0       0.0      NaN
# 9   2021-03-24     9         14.1      49.9        1.9       0.0      NaN
# 10  2021-03-24    10         15.7      48.0        1.2       0.0      NaN
# 11  2021-03-24    11         16.5      46.1        1.9       0.0      NaN
# ...

# %%
# %run test_db_insert.py
# Out:
# ✅ 2021-03-24 날씨 데이터 이미 존재 (24행) → SKIP
# ✅ Calendar 2021-03-24 존재: {'date': '2021-03-24', 'year': 2021, 'month': 3, 'day': 24, 'weekday': 3, 'weekend': 0, 'holiday': 0}
#
# 다음: python test_predict.py

# %%
# %run test_predict.py
# Out:
# ...
# predictor1.py + power_db_operations.py 통합 테스트
# 대상 날짜: 2021-03-24
# ...
#
# [방법 1] DB → get_prediction_variables → predict_with_input
# --------------------------------------------------
# ✅ DB 조회 완료: 24행 × 11컬럼
#
# [입력 DataFrame]
#           Date  hour  temperature  humidity  windspeed  rainfall op_code output  weekday  weekend  holiday
# 0   2021-03-24     0         -0.9      69.8        2.1       0.0    None   None        3        0        0
# 1   2021-03-24     1         -0.2      69.2        1.7       0.0    None   None        3        0        0
# 2   2021-03-24     2          0.7      69.5        1.6       0.0    None   None        3        0        0
# 3   2021-03-24     3          1.8      65.8        1.6       0.0    None   None        3        0        0
# 4   2021-03-24     4          3.6      61.1        1.1       0.0    None   None        3        0        0
# 5   2021-03-24     5          5.5      59.6        1.9       0.0    None   None        3        0        0
# ...

# %%
import os
print(os.listdir('./test_data'))
# Out:
# ['compare_sets_2021-03-24.csv', 'result_db_2021-03-24.csv', 'result_Mixed_2021-03-24.csv', 'result_Set_A_2021-03-24.csv', 'result_Set_B_2021-03-24.csv', 'result_Set_C_2021-03-24.csv', 'test_input_mixed.csv', 'test_input_SetA.csv', 'test_input_SetB.csv', 'test_input_SetC.csv']

# %%
import pandas as pd
df = pd.read_csv('./test_data/result_Mixed_2021-03-24.csv', encoding='utf-8-sig')
df
# Out:
#           Date  hour  temperature  humidity  windspeed  rainfall  op_code  \
# 0   2021-03-24     0          NaN       NaN        NaN       NaN      NaN
# 1   2021-03-24     1          NaN       NaN        NaN       NaN      NaN
# 2   2021-03-24     2          NaN       NaN        NaN       NaN      NaN
# 3   2021-03-24     3          NaN       NaN        NaN       NaN      NaN
# 4   2021-03-24     4          NaN       NaN        NaN       NaN      NaN
# 5   2021-03-24     5          NaN       NaN        NaN       NaN      NaN
# 6   2021-03-24     6          NaN       NaN        NaN       NaN      NaN
# 7   2021-03-24     7          NaN       NaN        NaN       NaN      NaN
# 8   2021-03-24     8         12.3      51.5        2.0       0.0      NaN
# 9   2021-03-24     9         14.1      49.9        1.9       0.0      NaN
# 10  2021-03-24    10         15.7      48.0        1.2       0.0      NaN
# 11  2021-03-24    11         16.5      46.1        1.9       0.0      NaN
# ...

# %%
import pandas as pd
df = pd.read_csv('./test_data/result_Mixed_2021-03-24.csv', encoding='utf-8-sig')
df
# Out:
#           Date  hour  temperature  humidity  windspeed  rainfall  op_code  \
# 0   2021-03-24     0          NaN       NaN        NaN       NaN      NaN
# 1   2021-03-24     1          NaN       NaN        NaN       NaN      NaN
# 2   2021-03-24     2          NaN       NaN        NaN       NaN      NaN
# 3   2021-03-24     3          NaN       NaN        NaN       NaN      NaN
# 4   2021-03-24     4          NaN       NaN        NaN       NaN      NaN
# 5   2021-03-24     5          NaN       NaN        NaN       NaN      NaN
# 6   2021-03-24     6          NaN       NaN        NaN       NaN      NaN
# 7   2021-03-24     7          NaN       NaN        NaN       NaN      NaN
# 8   2021-03-24     8         12.3      51.5        2.0       0.0      NaN
# 9   2021-03-24     9         14.1      49.9        1.9       0.0      NaN
# 10  2021-03-24    10         15.7      48.0        1.2       0.0      NaN
# 11  2021-03-24    11         16.5      46.1        1.9       0.0      NaN
# ...
