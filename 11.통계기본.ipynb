# %%
import numpy as np

# %%
import scipy
import scipy.stats as stats

# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
print(np.__version__)
# Out:
# 2.2.5

# %%
print(scipy.__version__)
# Out:
# 1.15.3

# %%
print(pd.__version__)
# Out:
# 2.3.3

# %%
print(plt.__version__)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 print(plt.__version__)
#
# AttributeError: module 'matplotlib.pyplot' has no attribute '__version__'

# %%
a = np.array([1, 2, 3])
print(a.mean(), a.std())
# Out:
# 2.0 0.816496580927726

# %%
a = np.array([1,2,3,4])
type(a)
# Out:
# numpy.ndarray

# %%
from scipy.stats import norm
norm.mean(), norm.var()

# %%
a.mean(), a.std()
# Out:
# (np.float64(2.5), np.float64(1.118033988749895))

# %%
import pandas as pd
df = pd.DataFrame({"score":[70,80,90],"gender":['M','F','M']})
#type(df)
df.describe()
# Out:
#        score
# count    3.0
# mean    80.0
# std     10.0
# min     70.0
# 25%     75.0
# 50%     80.0
# 75%     85.0
# max     90.0

# %%
import matplotlib.pyplot as plt
plt.plot([1,2,3],[2,4,6])
plt.title('Test...')
plt.show()

# %%
pd.core.frame.DataFrame
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# # 중심 경향성

# %% [markdown]
# ## 평균

# %%
import numpy as np
data = [10, 20, 30, 40, 50, 60]
#sum(data)/len(data)
print(np.mean(data))
# Out:
# 35.0

# %%
prices = np.array([5000, 9000])
counts = np.array([8, 2])
weighted_avg = np.average(prices, weights=counts)
print(f"평균 구매값: {weighted_avg:.0f}원")
# Out:
# 평균 구매값: 5800원

# %%
import numpy as np

# 1. 각 상품의 가격 (데이터 값)
prices = np.array([5000, 9000])

# 2. 각 상품의 구매 개수 (가중치)
counts = np.array([8, 2])

# 3. np.average 함수를 사용하여 가중평균 계산
weighted_avg = np.average(prices, weights=counts)

print(f"평균 구매값: {weighted_avg:.0f}원")

# %%
# 조종사의 평균 점수
data = {
    '점수': [97, 94, 92, 91, 90, 89, 78, 60],
    '인원수': [4, 11, 12, 21, 30, 12, 9, 1]  # 총 100명
}

#넘파이로 바로 가중평균 구하기
import numpy as np
weighted_mean = np.average(data['점수'], weights=data['인원수'])
print(weighted_mean)
# Out:
# 89.67

# %%
total_people = sum(data['인원수'])

print(f'#전채평가대상자 수{total_people}')
print(f'#평균점수 {weighted_score}')
risk_score = weighted_score
print(f'#기준미달{risk_score}'인 조종사가 { }입니다.')
# Out:
#   Cell In[6], line 6
#     print(f'#기준미달{risk_score}'인 조종사가 { }입니다.')
#                                             ^
# SyntaxError: unterminated string literal (detected at line 6)

# %%
import numpy as np

# 초기 매출
initial = 100

# 시나리오 적용
step1 = initial * 2.0      # +100%
step2 = step1 * 0.5        # -50%
final = step2

print(f"초기: {initial}만원")
print(f"1차 후: {step1}만원")
print(f"최종: {final}만원")
print(f"\n실제 변화: {((final/initial - 1) * 100):.1f}%")

# 산술평균
arithmetic = (100 + (-50)) / 2
print(f"산술평균: {arithmetic:.1f}%")

# 기하평균
geometric = (np.sqrt(2.0 * 0.5) - 1) * 100
print(f"기하평균: {geometric:.1f}%")
# Out:
# 초기: 100만원
# 1차 후: 200.0만원
# 최종: 100.0만원
#
# 실제 변화: 0.0%
# 산술평균: 25.0%
# 기하평균: 0.0%

# %%
import numpy as np
from scipy import stats

# 1. 데이터: 갈 때 100km/h, 올 때 50km/h
speeds = [100, 50]

# 2. 평균 계산 비교
# A. 산술평균 (오답)
arithmetic = np.mean(speeds)

# B. 조화평균 (정답)
harmonic = stats.hmean(speeds)

# 3. 결과 리포트
print(f"데이터: {speeds}")
print("-" * 35)
print(f"1. [❌ 오류] 산술평균: {arithmetic:.2f} km/h")
print("-" * 35)
print(f"2. [✅ 정답] 조화평균: {harmonic:.2f} km/h")
print(f"   >> 해석: '느린 구간(50) 때문에 전체 효율이 급감했습니다.'")
print(f"   >> 실제 물리적 평균 속도는 66.67km/h가 맞습니다.")
# Out:
# 데이터: [100, 50]
# -----------------------------------
# 1. [❌ 오류] 산술평균: 75.00 km/h
# -----------------------------------
# 2. [✅ 정답] 조화평균: 66.67 km/h
#    >> 해석: '느린 구간(50) 때문에 전체 효율이 급감했습니다.'
#    >> 실제 물리적 평균 속도는 66.67km/h가 맞습니다.

# %%
import numpy as np
data = [10, 20, 30, 40, 50]
median_value = np.median(data)
print(median_value) #30
median_value
# Out:
# 30.0
# np.float64(30.0)

# %%
scores = [65, 75, 80, 85, 95]
# 백분위수 계산
p25 = np.percentile(scores, 25) #Q1
p50 = np.percentile(scores, 50) #중앙값
p75 = np.percentile(scores, 75) #Q3

print(f"25번째 백분위수: {p25}")  # 75.0
print(f"50번째 백분위수(중앙값): {p50}")  # 80.0
print(f"75번째 백분위수: {p75}")  # 85.0
print(f"사분위간 범위(IQR): {p75 - p25}")  # 10.0
# Out:
# 25번째 백분위수: 75.0
# 50번째 백분위수(중앙값): 80.0
# 75번째 백분위수: 85.0
# 사분위간 범위(IQR): 10.0

# %%
scores = [70, 80, 80, 90, 60, 80, 70]
counts = {}

for x in scores:
    if x in counts:
        counts[x] += 1
    else:
        counts[x] = 1

counts
# 결과
{70: 2, 80: 3, 90: 1, 60: 1}
#최빈값은 ? 80

#함수로 구하기
mode = max(counts, key=counts.get)
mode
# Out:
# 80

# %%
# 판다스로 최빈값 가져오기
import pandas as pd
score_data = pd.Series(scores)
#pd.DataFrame(scores)
score_data.mode()
# Out:
# 0    80
# dtype: int64

# %% [markdown]
# # 변동성 - 범위

# %%
data1 = [50, 50, 50, 50, 50]
data2 = [10, 30, 50, 70, 90]
data3 = [0, 25, 50, 75, 100]

np.mean(data1), np.mean(data2), np.mean(data3)
# Out:
# (np.float64(50.0), np.float64(50.0), np.float64(50.0))

# %%
#평균은 같지만, 느낌이 다른 데이터

A = [50, 50, 50, 50, 50]
B = [10, 30, 50, 70, 90]
avg1 = sum(A) / len(A)  # 50
avg2 = sum(B) / len(B)  # 50
avg1, avg2

#평균 기준 변동성 계산
mean = sum(B) / len(B)  # 50
[x - mean for x in B]

# %% [markdown]
# # 변동성 - 분산

# %%
data1 = [50, 50, 50, 50, 50]
data2 = [10, 30, 50, 70, 90]
data3 = [0, 25, 50, 75, 100]
np.var(data2), np.var(data3)
# Out:
# (np.float64(800.0), np.float64(1250.0))

# %%
np.std(data2), np.std(data3)
# Out:
# (np.float64(28.284271247461902), np.float64(35.35533905932738))

# %%
data = [
    [47, 10, 31, 25, 20],
    [2, 11, 31, 25, 21],
    [44, 14, 15, 26, 21],
    [41, 14, 16, 26, 21],
    [7, 30, 17, 27, 24],
    [6, 30, 16, 29, 24],
    [35, 32, 15, 29, 23],
    [38, 33, 19, 28, 20],
    [35, 34, 18, 29, 21],
    [36, 32, 16, 27, 20],
]
data
# Out:
# [[47, 10, 31, 25, 20],
#  [2, 11, 31, 25, 21],
#  [44, 14, 15, 26, 21],
#  [41, 14, 16, 26, 21],
#  [7, 30, 17, 27, 24],
#  [6, 30, 16, 29, 24],
#  [35, 32, 15, 29, 23],
#  [38, 33, 19, 28, 20],
#  [35, 34, 18, 29, 21],
#  [36, 32, 16, 27, 20]]

# %%
df = pd.DataFrame(data, columns=['A','B','C','D','E'])
df
# Out:
#     A   B   C   D   E
# 0  47  10  31  25  20
# 1   2  11  31  25  21
# 2  44  14  15  26  21
# 3  41  14  16  26  21
# 4   7  30  17  27  24
# 5   6  30  16  29  24
# 6  35  32  15  29  23
# 7  38  33  19  28  20
# 8  35  34  18  29  21
# 9  36  32  16  27  20

# %%
import matplotlib.pyplot as plt
plt.hist(df)
# Out:
# (array([[ 2.,  1.,  0.,  0.,  0.,  0.,  0.,  3.,  2.,  2.],
#         [ 0.,  1.,  3.,  0.,  0.,  0.,  5.,  1.,  0.,  0.],
#         [ 0.,  0.,  2.,  6.,  0.,  0.,  2.,  0.,  0.,  0.],
#         [ 0.,  0.,  0.,  0.,  0.,  7.,  3.,  0.,  0.,  0.],
#         [ 0.,  0.,  0.,  0., 10.,  0.,  0.,  0.,  0.,  0.]]),
#  array([ 2. ,  6.5, 11. , 15.5, 20. , 24.5, 29. , 33.5, 38. , 42.5, 47. ]),
#  <a list of 5 BarContainer objects>)

# %%
plt.hist(df['A'])
# Out:
# (array([2., 1., 0., 0., 0., 0., 0., 3., 2., 2.]),
#  array([ 2. ,  6.5, 11. , 15.5, 20. , 24.5, 29. , 33.5, 38. , 42.5, 47. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(df['B'])
# Out:
# (array([2., 2., 0., 0., 0., 0., 0., 0., 2., 4.]),
#  array([10. , 12.4, 14.8, 17.2, 19.6, 22. , 24.4, 26.8, 29.2, 31.6, 34. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(df['C'])
# Out:
# (array([5., 2., 1., 0., 0., 0., 0., 0., 0., 2.]),
#  array([15. , 16.6, 18.2, 19.8, 21.4, 23. , 24.6, 26.2, 27.8, 29.4, 31. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(df['D'])
# Out:
# (array([2., 0., 2., 0., 0., 2., 0., 1., 0., 3.]),
#  array([25. , 25.4, 25.8, 26.2, 26.6, 27. , 27.4, 27.8, 28.2, 28.6, 29. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(df['E'])
# Out:
# (array([3., 0., 4., 0., 0., 0., 0., 1., 0., 2.]),
#  array([20. , 20.4, 20.8, 21.2, 21.6, 22. , 22.4, 22.8, 23.2, 23.6, 24. ]),
#  <BarContainer object of 10 artists>)

# %%
for col in df:
    #print(col)
    plt.hist(df[col])
    plt.show()

# %% [markdown]
# ## 첨도
#
# 양의 첨도 : 정규분포보다 값의 크기만큼 뽀족하다. 꼬리가 두껍다.
# 음의 첨도 : 정규분포보다 값의 크기만큼  평평하다. 꼬리가 얇다.

# %%
from scipy.stats import kurtosis
positive_kurtosis = [
    50, 50, 50, 50, 50,
    48, 52,
    35, 65
]
negative_kurtosis = [
    42, 44, 46, 48,
    52, 54, 56, 58
]
pos_kurtosis_value = kurtosis(positive_kurtosis )
neg_kurtosis_value = kurtosis(negative_kurtosis )

print(pos_kurtosis_value, neg_kurtosis_value )
# Out:
# 1.345540702885148 -1.4266666666666667

# %%
plt.hist(positive_kurtosis)
# Out:
# (array([1., 0., 0., 0., 1., 6., 0., 0., 0., 1.]),
#  array([35., 38., 41., 44., 47., 50., 53., 56., 59., 62., 65.]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(negative_kurtosis)
# Out:
# (array([1., 1., 1., 1., 0., 0., 1., 1., 1., 1.]),
#  array([42. , 43.6, 45.2, 46.8, 48.4, 50. , 51.6, 53.2, 54.8, 56.4, 58. ]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# ## 왜도 (Skewness)

# %%
from scipy.stats import skew #scipy 전체 가져오면 커서 skew만 가져옴

data = [10, 20, 30, 40, 100]  # 오른쪽으로 치우친 데이터
skew_value = skew(data)
print(skew_value)  # 양수 (오른쪽 꼬리)
# Out:
# 1.1384199576606167
