# %% [markdown]
# # sys

# %%
import sys
print(sys.version)

import transformers
import datasets
import pandas

print("transformers:",transformers.__version__)
print("datasets:",datasets.__version__)
print("pandas:",pandas.__version__)
print("환경설정 완료")
# Out:
# 3.10.20 | packaged by conda-forge | (main, Mar  5 2026, 16:36:49) [MSC v.1944 64 bit (AMD64)]
# transformers: 5.4.0
# datasets: 4.8.4
# pandas: 2.3.3
# 환경설정 완료

# %% [markdown]
# # import Inference Clinent

# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
import os
from huggingface_hub import InferenceClient

client = InferenceClient(
    provider="hf-inference",
    api_key=os.environ["HF_TOKEN"],
)

result = client.translation(
    "트럼프 향후 2~3주 언급하며 극도로 강하게 이란 타격할것",
    model="Helsinki-NLP/opus-mt-tc-big-tr-en",
)

# %%
result
# Out:
# TranslationOutput(translation_text='')

# %% [markdown]
# # 1 classifier = pipeline("text-classification")

# %%
from transformers import pipeline

# task만 지정하면 기본 모델 자동 로드
# 기본 모델: distilbert/distilbert-base-uncased-finetuned-sst-2-english
classifier = pipeline("text-classification")

result = classifier("SpaceX reportedly files plans for massive IPO")
print(result)
# [{'label': 'POSITIVE', 'score': 0.9998}]
# Out:
# No model was supplied, defaulted to distilbert/distilbert-base-uncased-finetuned-sst-2-english and revision 714eb0f.
# Using a pipeline without specifying a model name and revision in production is not recommended.
# Loading weights:   0%|          | 0/104 [00:00<?, ?it/s]
# [{'label': 'NEGATIVE', 'score': 0.9867795705795288}]

# %%
from transformers import pipeline

# task만 지정하면 기본 모델 자동 로드
# 기본 모델: distilbert/distilbert-base-uncased-finetuned-sst-2-english
classifier = pipeline("text-classification")

result = classifier("As arms agreements fray, China secretly expands its nuclear weapons infrastructure")
print(result)
# [{'label': 'POSITIVE', 'score': 0.9998}]
# Out:
# No model was supplied, defaulted to distilbert/distilbert-base-uncased-finetuned-sst-2-english and revision 714eb0f.
# Using a pipeline without specifying a model name and revision in production is not recommended.
# Loading weights:   0%|          | 0/104 [00:00<?, ?it/s]
# [{'label': 'POSITIVE', 'score': 0.8897764086723328}]

# %%
domain_text = [
    "SpaceX reportedly files plans for massive IPO",
    "As arms agreements fray, China secretly expands its nuclear weapons infrastructure",
]

# %% [markdown]
# # 2 model="ProsusAI/finbert"

# %%
# 2번 모델로 domain_text 테스트
from transformers import pipeline

classifier = pipeline("text-classification", model="ProsusAI/finbert")

domain_text = domain_text = [
    "Samsung Electronics posts record quarterly revenue driven by AI chip demand",         # 삼성전자, AI 칩 수요로 분기 매출 사상 최대
    "Major bank collapses after massive fraud scandal exposed",                            # 대형 은행, 대규모 사기 스캔들 폭로 후 파산
    "NVIDIA stock jumps 15% on strong data center growth forecast",                        # 엔비디아 주가, 데이터센터 성장 전망에 15% 급등
    "Oil prices crash as OPEC fails to reach production agreement",                        # OPEC 감산 합의 실패로 유가 폭락
    "Amazon announces $10 billion investment in renewable energy",                         # 아마존, 재생에너지에 100억 달러 투자 발표
    "Inflation hits 10-year high, consumer spending declines sharply",                     # 인플레이션 10년래 최고, 소비지출 급감
    "Google unveils revolutionary AI model surpassing human performance",                  # 구글, 인간 능력 초월하는 혁신적 AI 모델 공개
]

results_fin = classifier(domain_text)
for text, result in zip(domain_text, results_fin):
    print(f"입력: {text}")
    print(f"결과: {result['label']} ({result['score']:.4f})")
    print()
# Out:
# config.json:   0%|          | 0.00/758 [00:00<?, ?B/s]
# c:\Users\Admin\miniconda3\envs\hf-nlp\lib\site-packages\huggingface_hub\file_download.py:129: UserWarning: `huggingface_hub` cache-system uses symlinks by default to efficiently store duplicated files but your machine does not support them in C:\Users\Admin\.cache\huggingface\hub\models--ProsusAI--finbert. Caching files will still work but in a degraded version that might require more space on your disk. This warning can be disabled by setting the `HF_HUB_DISABLE_SYMLINKS_WARNING` environment variable. For more details, see https://huggingface.co/docs/huggingface_hub/how-to-cache#limitations.
# To support symlinks on Windows, you either need to activate Developer Mode or to run Python as an administrator. In order to activate developer mode, see this article: https://docs.microsoft.com/en-us/windows/apps/get-started/enable-your-device-for-development
#   warnings.warn(message)
# pytorch_model.bin:   0%|          | 0.00/438M [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/201 [00:00<?, ?it/s]
# BertForSequenceClassification LOAD REPORT from: ProsusAI/finbert
# Key                          | Status     |  |
# -----------------------------+------------+--+-
# bert.embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED:	can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# tokenizer_config.json:   0%|          | 0.00/252 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/438M [00:00<?, ?B/s]
# vocab.txt: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# 입력: Samsung Electronics posts record quarterly revenue driven by AI chip demand
# 결과: positive (0.9212)
#
# 입력: Major bank collapses after massive fraud scandal exposed
# 결과: negative (0.8983)
#
# 입력: NVIDIA stock jumps 15% on strong data center growth forecast
# 결과: positive (0.9309)
#
# 입력: Oil prices crash as OPEC fails to reach production agreement
# 결과: negative (0.9594)
#
# 입력: Amazon announces $10 billion investment in renewable energy
# 결과: neutral (0.7008)
#
# 입력: Inflation hits 10-year high, consumer spending declines sharply
# 결과: negative (0.9557)
#
# 입력: Google unveils revolutionary AI model surpassing human performance
# 결과: neutral (0.6965)

# %%
result = classifier(domain_text)

# %%
for text, result in zip(domain_text, results_fin):
    print(f"입력: {text}")
    print(f"결과: {result}")

# %%
pipeline("text-classification", model="snulp/KR-FinBert-SC")

# %%
pipeline("sentiment-analysis", "tabularisai/multilingual-sentiment-analysis")

# %% [markdown]
# # 3 model="snunlp/KR-FinBert-SC"

# %%
# 3번 모델로 한국어 뉴스 테스트
from transformers import pipeline

classifier = pipeline("text-classification", model="snunlp/KR-FinBert-SC")

domain_text_kr = [
    "삼성전자, AI 칩 수요로 분기 매출 사상 최대 기록",
    "대형 은행, 대규모 사기 스캔들 폭로 후 파산",
    "엔비디아 주가, 데이터센터 성장 전망에 15% 급등",
    "OPEC 감산 합의 실패로 국제 유가 폭락",
    "아마존, 재생에너지에 100억 달러 투자 발표",
    "인플레이션 10년래 최고치, 소비지출 급감",
    "구글, 인간 능력 초월하는 혁신적 AI 모델 공개",
]

results_kr = classifier(domain_text_kr)
for text, result in zip(domain_text_kr, results_kr):
    print(f"입력: {text}")
    print(f"결과: {result['label']} ({result['score']:.4f})")
    print()
# Out:
# config.json:   0%|          | 0.00/881 [00:00<?, ?B/s]
# c:\Users\Admin\miniconda3\envs\hf-nlp\lib\site-packages\huggingface_hub\file_download.py:129: UserWarning: `huggingface_hub` cache-system uses symlinks by default to efficiently store duplicated files but your machine does not support them in C:\Users\Admin\.cache\huggingface\hub\models--snunlp--KR-FinBert-SC. Caching files will still work but in a degraded version that might require more space on your disk. This warning can be disabled by setting the `HF_HUB_DISABLE_SYMLINKS_WARNING` environment variable. For more details, see https://huggingface.co/docs/huggingface_hub/how-to-cache#limitations.
# To support symlinks on Windows, you either need to activate Developer Mode or to run Python as an administrator. In order to activate developer mode, see this article: https://docs.microsoft.com/en-us/windows/apps/get-started/enable-your-device-for-development
#   warnings.warn(message)
# pytorch_model.bin:   0%|          | 0.00/406M [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/201 [00:00<?, ?it/s]
# BertForSequenceClassification LOAD REPORT from: snunlp/KR-FinBert-SC
# Key                          | Status     |  |
# -----------------------------+------------+--+-
# bert.embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED:	can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# tokenizer_config.json:   0%|          | 0.00/372 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/406M [00:00<?, ?B/s]
# vocab.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# 입력: 삼성전자, AI 칩 수요로 분기 매출 사상 최대 기록
# 결과: positive (0.9999)
#
# 입력: 대형 은행, 대규모 사기 스캔들 폭로 후 파산
# 결과: negative (0.9997)
#
# 입력: 엔비디아 주가, 데이터센터 성장 전망에 15% 급등
# 결과: positive (0.9999)
#
# 입력: OPEC 감산 합의 실패로 국제 유가 폭락
# 결과: neutral (0.9776)
#
# 입력: 아마존, 재생에너지에 100억 달러 투자 발표
# 결과: neutral (0.9998)
#
# 입력: 인플레이션 10년래 최고치, 소비지출 급감
# 결과: neutral (0.9908)
#
# 입력: 구글, 인간 능력 초월하는 혁신적 AI 모델 공개
# 결과: positive (0.9988)

# %% [markdown]
# # 4 다국어 감성 분석 모델

# %%
# 4번 다국어 감성 분석 모델
from transformers import pipeline

classifier = pipeline("sentiment-analysis", model="tabularisai/multilingual-sentiment-analysis")

texts = [
    "Trump warns of extremely powerful military strike against Iran within weeks",  # 영어 (부정)
    "트럼프, 수주 내 이란에 대한 극도로 강력한 군사 타격 경고",                             # 한국어 (부정)
    "トランプ氏、数週間以内にイランへの強力な軍事攻撃を警告",                                 # 일본어 (부정)
    "BTS announces surprise world tour with free tickets for fans",                 # 영어 (긍정)
    "방탄소년단, 팬들에게 무료 티켓 제공하며 깜짝 월드투어 발표",                             # 한국어 (긍정)
    "BTS、ファンに無料チケットを提供しサプライズワールドツアーを発表",                           # 일본어 (긍정)
    "Hyundai Motor recalls 500,000 vehicles due to engine defect",                  # 영어 (부정)
    "현대자동차, 엔진 결함으로 50만대 리콜 결정",                                        # 한국어 (부정)
    "現代自動車、エンジン欠陥で50万台をリコール決定",                                      # 일본어 (부정)
]

# Expected: 부정, 부정, 부정, 긍정, 긍정, 긍정, 부정, 부정, 부정

results = classifier(texts)
for text, result in zip(texts, results):
    print(f"입력: {text}")
    print(f"결과: {result['label']} ({result['score']:.4f})")
    print()
# Out:
# config.json:   0%|          | 0.00/851 [00:00<?, ?B/s]
# c:\Users\Admin\miniconda3\envs\hf-nlp\lib\site-packages\huggingface_hub\file_download.py:129: UserWarning: `huggingface_hub` cache-system uses symlinks by default to efficiently store duplicated files but your machine does not support them in C:\Users\Admin\.cache\huggingface\hub\models--tabularisai--multilingual-sentiment-analysis. Caching files will still work but in a degraded version that might require more space on your disk. This warning can be disabled by setting the `HF_HUB_DISABLE_SYMLINKS_WARNING` environment variable. For more details, see https://huggingface.co/docs/huggingface_hub/how-to-cache#limitations.
# To support symlinks on Windows, you either need to activate Developer Mode or to run Python as an administrator. In order to activate developer mode, see this article: https://docs.microsoft.com/en-us/windows/apps/get-started/enable-your-device-for-development
#   warnings.warn(message)
# model.safetensors:   0%|          | 0.00/541M [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/104 [00:00<?, ?it/s]
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/125 [00:00<?, ?B/s]
# 입력: Trump warns of extremely powerful military strike against Iran within weeks
# 결과: Neutral (0.3584)
#
# 입력: 트럼프, 수주 내 이란에 대한 극도로 강력한 군사 타격 경고
# 결과: Neutral (0.6223)
#
# 입력: トランプ氏、数週間以内にイランへの強力な軍事攻撃を警告
# 결과: Neutral (0.8466)
#
# 입력: BTS announces surprise world tour with free tickets for fans
# 결과: Neutral (0.6267)
#
# 입력: 방탄소년단, 팬들에게 무료 티켓 제공하며 깜짝 월드투어 발표
# 결과: Positive (0.5635)
#
# 입력: BTS、ファンに無料チケットを提供しサプライズワールドツアーを発表
# 결과: Neutral (0.8115)
#
# 입력: Hyundai Motor recalls 500,000 vehicles due to engine defect
# 결과: Neutral (0.8463)
#
# 입력: 현대자동차, 엔진 결함으로 50만대 리콜 결정
# 결과: Neutral (0.9171)
#
# 입력: 現代自動車、エンジン欠陥で50万台をリコール決定
# 결과: Neutral (0.9326)

# %% [markdown]
# # 5 다국어 BERT

# %%
# 5번 빈칸 채우기 (다국어 BERT)
from transformers import pipeline

unmasker = pipeline("fill-mask", model="bert-base-multilingual-cased")

# 영어: Tesla is the world's largest [MASK] vehicle manufacturer.
result_en = unmasker("Tesla is the world's largest [MASK] vehicle manufacturer.")
print("=== 영어 ===")
print("입력: Tesla is the world's largest [MASK] vehicle manufacturer.")
for r in result_en[:3]:
    print(f"  예측: {r['token_str']} (score: {r['score']:.4f})")
print()

# 한국어: 삼성전자는 세계 최대의 [MASK] 기업이다.
result_kr = unmasker("삼성전자는 세계 최대의 [MASK] 기업이다.")
print("=== 한국어 ===")
print("입력: 삼성전자는 세계 최대의 [MASK] 기업이다.")
for r in result_kr[:3]:
    print(f"  예측: {r['token_str']} (score: {r['score']:.4f})")
print()

# 일본어: 東京は日本の[MASK]です。
result_jp = unmasker("東京は日本の[MASK]です。")
print("=== 일본어 ===")
print("입력: 東京は日本の[MASK]です。")
for r in result_jp[:3]:
    print(f"  예측: {r['token_str']} (score: {r['score']:.4f})")
print()
# Out:
# config.json:   0%|          | 0.00/625 [00:00<?, ?B/s]
# c:\Users\Admin\miniconda3\envs\hf-nlp\lib\site-packages\huggingface_hub\file_download.py:129: UserWarning: `huggingface_hub` cache-system uses symlinks by default to efficiently store duplicated files but your machine does not support them in C:\Users\Admin\.cache\huggingface\hub\models--bert-base-multilingual-cased. Caching files will still work but in a degraded version that might require more space on your disk. This warning can be disabled by setting the `HF_HUB_DISABLE_SYMLINKS_WARNING` environment variable. For more details, see https://huggingface.co/docs/huggingface_hub/how-to-cache#limitations.
# To support symlinks on Windows, you either need to activate Developer Mode or to run Python as an administrator. In order to activate developer mode, see this article: https://docs.microsoft.com/en-us/windows/apps/get-started/enable-your-device-for-development
#   warnings.warn(message)
# model.safetensors:   0%|          | 0.00/714M [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/202 [00:00<?, ?it/s]
# BertForMaskedLM LOAD REPORT from: bert-base-multilingual-cased
# Key                         | Status     |  |
# ----------------------------+------------+--+-
# cls.seq_relationship.bias   | UNEXPECTED |  |
# bert.pooler.dense.bias      | UNEXPECTED |  |
# bert.pooler.dense.weight    | UNEXPECTED |  |
# cls.seq_relationship.weight | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED:	can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# tokenizer_config.json:   0%|          | 0.00/49.0 [00:00<?, ?B/s]
# vocab.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# === 영어 ===
# 입력: Tesla is the world's largest [MASK] vehicle manufacturer.
#   예측: Tesla (score: 0.8841)
#   예측: motor (score: 0.0540)
#   예측: automobile (score: 0.0087)
#
# === 한국어 ===
# 입력: 삼성전자는 세계 최대의 [MASK] 기업이다.
#   예측: 삼 (score: 0.1699)
#   예측: 세계 (score: 0.0773)
#   예측: 주요 (score: 0.0707)
#
# === 일본어 ===
# 입력: 東京は日本の[MASK]です。
#   예측: 道 (score: 0.1708)
#   예측: 国 (score: 0.0922)
#   예측: 都 (score: 0.0887)

# %% [markdown]
# # 6 한국어 특화 BERT

# %%
# 6번 빈칸 채우기 (한국어 특화 BERT)
from transformers import pipeline

unmasker = pipeline("fill-mask", model="klue/bert-base")

# 한국어 1: 대한민국의 수도는 [MASK]이다.
result1 = unmasker("대한민국의 수도는 [MASK]이다.")
print("=== 한국어 1 ===")
print("입력: 대한민국의 수도는 [MASK]이다.")
for r in result1[:3]:
    print(f"  예측: {r['token_str']} (score: {r['score']:.4f})")
print()

# 한국어 2: 삼성전자는 반도체와 [MASK]를 생산하는 글로벌 기업이다.
result2 = unmasker("삼성전자는 반도체와 [MASK]를 생산하는 글로벌 기업이다.")
print("=== 한국어 2 ===")
print("입력: 삼성전자는 반도체와 [MASK]를 생산하는 글로벌 기업이다.")
for r in result2[:3]:
    print(f"  예측: {r['token_str']} (score: {r['score']:.4f})")
print()

# 한국어 3: 인공지능 기술은 앞으로 [MASK] 분야에서 가장 큰 변화를 가져올 것이다.
result3 = unmasker("인공지능 기술은 앞으로 [MASK] 분야에서 가장 큰 변화를 가져올 것이다.")
print("=== 한국어 3 ===")
print("입력: 인공지능 기술은 앞으로 [MASK] 분야에서 가장 큰 변화를 가져올 것이다.")
for r in result3[:3]:
    print(f"  예측: {r['token_str']} (score: {r['score']:.4f})")
print()
# Out:
# config.json:   0%|          | 0.00/425 [00:00<?, ?B/s]
# c:\Users\Admin\miniconda3\envs\hf-nlp\lib\site-packages\huggingface_hub\file_download.py:129: UserWarning: `huggingface_hub` cache-system uses symlinks by default to efficiently store duplicated files but your machine does not support them in C:\Users\Admin\.cache\huggingface\hub\models--klue--bert-base. Caching files will still work but in a degraded version that might require more space on your disk. This warning can be disabled by setting the `HF_HUB_DISABLE_SYMLINKS_WARNING` environment variable. For more details, see https://huggingface.co/docs/huggingface_hub/how-to-cache#limitations.
# To support symlinks on Windows, you either need to activate Developer Mode or to run Python as an administrator. In order to activate developer mode, see this article: https://docs.microsoft.com/en-us/windows/apps/get-started/enable-your-device-for-development
#   warnings.warn(message)
# model.safetensors:   0%|          | 0.00/445M [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/202 [00:00<?, ?it/s]
# BertForMaskedLM LOAD REPORT from: klue/bert-base
# Key                          | Status     |  |
# -----------------------------+------------+--+-
# cls.seq_relationship.bias    | UNEXPECTED |  |
# bert.pooler.dense.bias       | UNEXPECTED |  |
# bert.embeddings.position_ids | UNEXPECTED |  |
# bert.pooler.dense.weight     | UNEXPECTED |  |
# cls.seq_relationship.weight  | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED:	can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# tokenizer_config.json:   0%|          | 0.00/289 [00:00<?, ?B/s]
# vocab.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/125 [00:00<?, ?B/s]
# === 한국어 1 ===
# 입력: 대한민국의 수도는 [MASK]이다.
#   예측: 서울 (score: 0.5955)
#   예측: 광화문 (score: 0.0811)
#   예측: 평양 (score: 0.0472)
#
# === 한국어 2 ===
# 입력: 삼성전자는 반도체와 [MASK]를 생산하는 글로벌 기업이다.
#   예측: 디스플레이 (score: 0.6050)
#   예측: LCD (score: 0.2128)
#   예측: 스마트폰 (score: 0.0483)
#
# === 한국어 3 ===
# 입력: 인공지능 기술은 앞으로 [MASK] 분야에서 가장 큰 변화를 가져올 것이다.
#   예측: 이 (score: 0.2605)
#   예측: 산업 (score: 0.0907)
#   예측: 모든 (score: 0.0894)

# %% [markdown]
# # 7 한국어 금융 특화 BERT

# %%
# 7번 빈칸 채우기 (한국어 금융 특화 BERT)
from transformers import pipeline

unmasker = pipeline("fill-mask", model="snunlp/KR-FinBert")

# 금융 1: 한국은행이 기준금리를 [MASK] 결정했다.
result1 = unmasker("한국은행이 기준금리를 [MASK] 결정했다.")
print("=== 금융 1 ===")
print("입력: 한국은행이 기준금리를 [MASK] 결정했다.")
for r in result1[:3]:
    print(f"  예측: {r['token_str']} (score: {r['score']:.4f})")
print()

# 금융 2: 코스피 지수가 장중 [MASK]를 기록하며 투자자들의 관심이 집중되었다.
result2 = unmasker("코스피 지수가 장중 [MASK]를 기록하며 투자자들의 관심이 집중되었다.")
print("=== 금융 2 ===")
print("입력: 코스피 지수가 장중 [MASK]를 기록하며 투자자들의 관심이 집중되었다.")
for r in result2[:3]:
    print(f"  예측: {r['token_str']} (score: {r['score']:.4f})")
print()

# 금융 3: 삼성전자 주가가 실적 발표 이후 [MASK] 전환했다.
result3 = unmasker("삼성전자 주가가 실적 발표 이후 [MASK] 전환했다.")
print("=== 금융 3 ===")
print("입력: 삼성전자 주가가 실적 발표 이후 [MASK] 전환했다.")
for r in result3[:3]:
    print(f"  예측: {r['token_str']} (score: {r['score']:.4f})")
print()
# Out:
# config.json:   0%|          | 0.00/655 [00:00<?, ?B/s]
# c:\Users\Admin\miniconda3\envs\hf-nlp\lib\site-packages\huggingface_hub\file_download.py:129: UserWarning: `huggingface_hub` cache-system uses symlinks by default to efficiently store duplicated files but your machine does not support them in C:\Users\Admin\.cache\huggingface\hub\models--snunlp--KR-FinBert. Caching files will still work but in a degraded version that might require more space on your disk. This warning can be disabled by setting the `HF_HUB_DISABLE_SYMLINKS_WARNING` environment variable. For more details, see https://huggingface.co/docs/huggingface_hub/how-to-cache#limitations.
# To support symlinks on Windows, you either need to activate Developer Mode or to run Python as an administrator. In order to activate developer mode, see this article: https://docs.microsoft.com/en-us/windows/apps/get-started/enable-your-device-for-development
#   warnings.warn(message)
# pytorch_model.bin:   0%|          | 0.00/406M [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/204 [00:00<?, ?it/s]
# BertForMaskedLM LOAD REPORT from: snunlp/KR-FinBert
# Key                          | Status     |  |
# -----------------------------+------------+--+-
# bert.embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED:	can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# tokenizer_config.json:   0%|          | 0.00/336 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/406M [00:00<?, ?B/s]
# vocab.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# === 금융 1 ===
# 입력: 한국은행이 기준금리를 [MASK] 결정했다.
#   예측: 인하 (score: 0.2977)
#   예측: 그대로 (score: 0.1250)
#   예측: 내려 (score: 0.0639)
#
# === 금융 2 ===
# 입력: 코스피 지수가 장중 [MASK]를 기록하며 투자자들의 관심이 집중되었다.
#   예측: 최고 (score: 0.6956)
#   예측: 마이너스 (score: 0.1241)
#   예측: 최저 (score: 0.0629)
#
# === 금융 3 ===
# 입력: 삼성전자 주가가 실적 발표 이후 [MASK] 전환했다.
#   예측: 상승 (score: 0.7227)
#   예측: 하락 (score: 0.2742)
#   예측: 적자 (score: 0.0003)
