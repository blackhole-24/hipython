# %% [markdown]
# # 시작하기

# %%
from IPython.display import HTML

HTML("""
<style>
/* Notebook 7 / JupyterLab */
.cm-editor, .cm-content {
    font-size: 30px !important;
    line-height: 1.4 !important;
}
</style>
""")
# Out:
# <style>
# /* Notebook 7 / JupyterLab */
# .cm-editor, .cm-content {
#     font-size: 30px !important;
#     line-height: 1.4 !important;
# }
# </style>

# %%
3000*2
# Out:
# 6000

# %%
print("hello python")
print(32)
print('hi')
print('계산 : ', 3000*2, '입니다')
# Out:
# hello python
# 32
# hi
# 계산 :  6000 입니다

# %%
sale = 20 * 2000
print("오늘 매출은 ",sale,"입니다")
# Out:
# 오늘 매출은  40000 입니다

# %%
# 성장율 = (이번달 매출 - 지난달 매출) / 지난달 매출 * 100
성장율 = (1500-1000)/1000*100
"이번달의 성장율은 100%입니다"
# Out:
# '이번달의 성장율은 100%입니다'

# %%
print("이번달의 성장율은 ",(1500-1000)/1000*100,"%입니다")
# Out:
# 이번달의 성장율은  50.0 %입니다

# %%
print("이번달의 성장율은 ",성장율,"%입니다")
# Out:
# 이번달의 성장율은  50.0 %입니다

# %%
이달매출 = 500
지난달매출 = 2500
성장율 = (이달매출-지난달매출)/지난달매출*100
print("이번달의 성장율은 ",성장율,"%입니다")
# Out:
# 이번달의 성장율은  -80.0 %입니다

# %%
이달매출 = input('이번달 매출액을 입력하세요')
지난달매출 = input('지난달 매출액을 입력하세요')
print(이달매출,지난달매출)
# Out:
# 이번달 매출액을 입력하세요 1000
# 지난달 매출액을 입력하세요 2000
# 1000 2000

# %%
#당신의 이름을 알려주세요
#이름님! 반갑습니다!!

# %%
name = input("당신의 이름을 알려주세요")
print(name+"님! 반갑습니다!!")
# Out:
# 당신의 이름을 알려주세요 영리쌤
# 영리쌤님! 반갑습니다!!

# %% [markdown]
# # print()의 활용

# %%
가격 = 1000
수량 = 10
매출 = 가격 * 수량
print(매출)
# Out:
# 10000

# %%
print("이번달 매출은", 매출, "입니다.", sep=" ")
# Out:
# 이번달 매출은 10000 입니다.

# %%
#apple, banana, cherry
과일목록1 = 'apple'
과일목록3 = 'banana'
print( 과일목록1,  과일목록2, sep=', ')
# Out:
# apple, banana

# %%
print( 과일목록1, 과일목록2,  과일목록3, sep='>')#sep=',\t '
# Out:
# apple>banana>banana

# %% [markdown]
# # data type

# %%
12345, '12345'
# Out:
# (12345, '12345')

# %%
type(12345), type('12345')
# Out:
# (int, str)

# %%
data = 12345
data2 = '12345'
type(data), type(data2)
# Out:
# (int, str)

# %%
12345+10, '12345'+'10'
# Out:
# (12355, '1234510')

# %%
data+10, data2+10
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 data+10, data2+10
#
# TypeError: can only concatenate str (not "int") to str

# %%
print("이번달 매출은", 매출, "입니다.", sep=" ")

# %%
name = 'ylee'
age = 20
#stringformat
print("나의 이름은 {}이고, 나이는 {}입니다.".format(name, age))
# Out:
# 나의 이름은 ylee이고, 나이는 20입니다.

# %%
#fstring
print(f"나의 이름은 {name}이고, 나이는 {age}입니다.")
# Out:
# 나의 이름은 ylee이고, 나이는 20입니다.

# %%
# 기본 입력
name = input("이름을 입력하세요: ")
print(f"입력한 이름: {name}")

# 숫자 입력 (문자열을 숫자로 변환)
age = int(input("나이를 입력하세요: "))
print(f"내년 나이: {age + 1}")

# %%
age = input('나이를 입력하세요: ')
age + 1
# Out:
# 나이를 입력하세요:  20
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[30], line 2
#       1 age = input('나이를 입력하세요: ')
# ----> 2 age + 1
#
# TypeError: can only concatenate str (not "int") to str

# %%
type(age)
# Out:
# str

# %%
type(int('10'))
# Out:
# int

# %%
int(age)+1
# Out:
# 21

# %%
type(int(age)+1)
# Out:
# int

# %%
age = '열살'
type(age)
# Out:
# str

# %%
age = 20.8
type(age)
# Out:
# float

# %%
student_name = 'ylee'
name_1 = 'ylee'

# %%
1_name = 'ylee'
# Out:
#   Cell In[39], line 1
#     1_name = 'ylee'
#      ^
# SyntaxError: invalid decimal literal

# %%
x = 10
a = 20

# %%
PI = 3.141592 #constant 상수

# %%
MAX_VALUE = 1000
MIN_VALUE = 0

# %%
#input()  #shift+tab 키 매개변수 확인
print(abs(-3.14)) #tab
# Out:
# 3.14

# %%
"".format()
# Out:
# ''

# %%
a = 30,20,10 #패킹
type(a), a
# Out:
# (tuple, (30, 20, 10))

# %%
x=30;
y=20; 
y1=10

# %%
x,y, y1 = a #언패킹
x,y
# Out:
# (30, 20)

# %%
b = 30,
type(b)
# Out:
# tuple

# %%
a = 10
b = a
a,b
# Out:
# (10, 10)

# %%
id(a), id(b)
# Out:
# (140715331185368, 140715331185368)

# %%
a=10
id(a), id(b) #(140715331185688, 140715331185368)
# Out:
# (140715331185368, 140715331185368)

# %%
user_name = 'ylee' #snake
userName = 'ylee' #camel
username = 'ylee'
_name = 'ylee' #private
__name__ = 'ylee' #더블언더스코어 '던더'
print(str(20)) #__str__()
_password = 1234
# Out:
# 20

# %%
a+b, a + b

# %%
a = 'hi'
b = 'Hi'
id(a), id(b)
# Out:
# (140715331228128, 2474963809696)

# %%
a = 'Hi'
id(a), id(b)
# Out:
# (2751099109856, 2751099109856)

# %%
a,b
# Out:
# ('hi', 'Hi')

# %% [markdown]
# # 변수의 영역 namespace
#
# 지역변수, 전역변수

# %%
def local_exam(): #사용자정의함수
    local_var = 100
    print(f"함수내부: {local_var}")
local_exam()
local_var = 200
local_exam()
print(f"함수외부: {local_var}")
# Out:
# 함수내부: 100
# 함수내부: 100
# 함수외부: 200

# %%
a = 0
def aa():
    global counter
    # temp = a + 1
    # a = temp
    #a = a + 1
    a += 1
    print(counter)

aa() #counter =1
aa() #
aa()
# Out:
# 1
# 2
# 3
