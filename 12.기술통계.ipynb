# %%
import numpy as np

# %%
import scipy
import scipy.stats as stats

# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
print(np.__version__)
# Out:
# 2.2.5

# %%
print(scipy.__version__)
# Out:
# 1.15.3

# %%
print(pd.__version__)
# Out:
# 2.3.3

# %%
print(plt.__version__)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 print(plt.__version__)
#
# AttributeError: module 'matplotlib.pyplot' has no attribute '__version__'

# %%
a = np.array([1, 2, 3])
print(a.mean(), a.std())
# Out:
# 2.0 0.816496580927726

# %%
a = np.array([1,2,3,4])
type(a)
# Out:
# numpy.ndarray

# %%
from scipy.stats import norm
norm.mean(), norm.var()

# %%
a.mean(), a.std()
# Out:
# (np.float64(2.5), np.float64(1.118033988749895))

# %%
import pandas as pd
df = pd.DataFrame({"score":[70,80,90],"gender":['M','F','M']})
#type(df)
df.describe()
# Out:
#        score
# count    3.0
# mean    80.0
# std     10.0
# min     70.0
# 25%     75.0
# 50%     80.0
# 75%     85.0
# max     90.0

# %%
import matplotlib.pyplot as plt
plt.plot([1,2,3],[2,4,6])
plt.title('Test...')
plt.show()

# %%
pd.core.frame.DataFrame
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# # 중심 경향성

# %% [markdown]
# ## 평균

# %%
import numpy as np
data = [10, 20, 30, 40, 50, 60]
#sum(data)/len(data)
print(np.mean(data))
# Out:
# 35.0

# %%
prices = np.array([5000, 9000])
counts = np.array([8, 2])
weighted_avg = np.average(prices, weights=counts)
print(f"평균 구매값: {weighted_avg:.0f}원")
# Out:
# 평균 구매값: 5800원

# %%
import numpy as np

# 1. 각 상품의 가격 (데이터 값)
prices = np.array([5000, 9000])

# 2. 각 상품의 구매 개수 (가중치)
counts = np.array([8, 2])

# 3. np.average 함수를 사용하여 가중평균 계산
weighted_avg = np.average(prices, weights=counts)

print(f"평균 구매값: {weighted_avg:.0f}원")

# %%
# 조종사의 평균 점수
data = {
    '점수': [97, 94, 92, 91, 90, 89, 78, 60],
    '인원수': [4, 11, 12, 21, 30, 12, 9, 1]  # 총 100명
}

#넘파이로 바로 가중평균 구하기
import numpy as np
weighted_mean = np.average(data['점수'], weights=data['인원수'])
print(weighted_mean)
# Out:
# 89.67

# %%
total_people = sum(data['인원수'])

print(f'#전채평가대상자 수{total_people}')
print(f'#평균점수 {weighted_score}')
risk_score = weighted_score
print(f'#기준미달{risk_score}'인 조종사가 { }입니다.')
# Out:
#   Cell In[6], line 6
#     print(f'#기준미달{risk_score}'인 조종사가 { }입니다.')
#                                             ^
# SyntaxError: unterminated string literal (detected at line 6)

# %%
import numpy as np

# 초기 매출
initial = 100

# 시나리오 적용
step1 = initial * 2.0      # +100%
step2 = step1 * 0.5        # -50%
final = step2

print(f"초기: {initial}만원")
print(f"1차 후: {step1}만원")
print(f"최종: {final}만원")
print(f"\n실제 변화: {((final/initial - 1) * 100):.1f}%")

# 산술평균
arithmetic = (100 + (-50)) / 2
print(f"산술평균: {arithmetic:.1f}%")

# 기하평균
geometric = (np.sqrt(2.0 * 0.5) - 1) * 100
print(f"기하평균: {geometric:.1f}%")
# Out:
# 초기: 100만원
# 1차 후: 200.0만원
# 최종: 100.0만원
#
# 실제 변화: 0.0%
# 산술평균: 25.0%
# 기하평균: 0.0%

# %%
import numpy as np
from scipy import stats

# 1. 데이터: 갈 때 100km/h, 올 때 50km/h
speeds = [100, 50]

# 2. 평균 계산 비교
# A. 산술평균 (오답)
arithmetic = np.mean(speeds)

# B. 조화평균 (정답)
harmonic = stats.hmean(speeds)

# 3. 결과 리포트
print(f"데이터: {speeds}")
print("-" * 35)
print(f"1. [❌ 오류] 산술평균: {arithmetic:.2f} km/h")
print("-" * 35)
print(f"2. [✅ 정답] 조화평균: {harmonic:.2f} km/h")
print(f"   >> 해석: '느린 구간(50) 때문에 전체 효율이 급감했습니다.'")
print(f"   >> 실제 물리적 평균 속도는 66.67km/h가 맞습니다.")
# Out:
# 데이터: [100, 50]
# -----------------------------------
# 1. [❌ 오류] 산술평균: 75.00 km/h
# -----------------------------------
# 2. [✅ 정답] 조화평균: 66.67 km/h
#    >> 해석: '느린 구간(50) 때문에 전체 효율이 급감했습니다.'
#    >> 실제 물리적 평균 속도는 66.67km/h가 맞습니다.

# %%
import numpy as np
data = [10, 20, 30, 40, 50]
median_value = np.median(data)
print(median_value) #30
median_value
# Out:
# 30.0
# np.float64(30.0)

# %%
scores = [65, 75, 80, 85, 95]
# 백분위수 계산
p25 = np.percentile(scores, 25) #Q1
p50 = np.percentile(scores, 50) #중앙값
p75 = np.percentile(scores, 75) #Q3

print(f"25번째 백분위수: {p25}")  # 75.0
print(f"50번째 백분위수(중앙값): {p50}")  # 80.0
print(f"75번째 백분위수: {p75}")  # 85.0
print(f"사분위간 범위(IQR): {p75 - p25}")  # 10.0
# Out:
# 25번째 백분위수: 75.0
# 50번째 백분위수(중앙값): 80.0
# 75번째 백분위수: 85.0
# 사분위간 범위(IQR): 10.0

# %%
scores = [70, 80, 80, 90, 60, 80, 70]
counts = {}

for x in scores:
    if x in counts:
        counts[x] += 1
    else:
        counts[x] = 1

counts
# 결과
{70: 2, 80: 3, 90: 1, 60: 1}
#최빈값은 ? 80

#함수로 구하기
mode = max(counts, key=counts.get)
mode
# Out:
# 80

# %%
# 판다스로 최빈값 가져오기
import pandas as pd
score_data = pd.Series(scores)
#pd.DataFrame(scores)
score_data.mode()
# Out:
# 0    80
# dtype: int64

# %% [markdown]
# # 변동성 - 범위

# %%
data1 = [50, 50, 50, 50, 50]
data2 = [10, 30, 50, 70, 90]
data3 = [0, 25, 50, 75, 100]

np.mean(data1), np.mean(data2), np.mean(data3)
# Out:
# (np.float64(50.0), np.float64(50.0), np.float64(50.0))

# %%
#평균은 같지만, 느낌이 다른 데이터

A = [50, 50, 50, 50, 50]
B = [10, 30, 50, 70, 90]
avg1 = sum(A) / len(A)  # 50
avg2 = sum(B) / len(B)  # 50
avg1, avg2

#평균 기준 변동성 계산
mean = sum(B) / len(B)  # 50
[x - mean for x in B]

# %% [markdown]
# # 변동성 - 분산

# %%
data1 = [50, 50, 50, 50, 50]
data2 = [10, 30, 50, 70, 90]
data3 = [0, 25, 50, 75, 100]
np.var(data2), np.var(data3)
# Out:
# (np.float64(800.0), np.float64(1250.0))

# %%
np.std(data2), np.std(data3)
# Out:
# (np.float64(28.284271247461902), np.float64(35.35533905932738))

# %%
data = [
    [47, 10, 31, 25, 20],
    [2, 11, 31, 25, 21],
    [44, 14, 15, 26, 21],
    [41, 14, 16, 26, 21],
    [7, 30, 17, 27, 24],
    [6, 30, 16, 29, 24],
    [35, 32, 15, 29, 23],
    [38, 33, 19, 28, 20],
    [35, 34, 18, 29, 21],
    [36, 32, 16, 27, 20],
]
data
# Out:
# [[47, 10, 31, 25, 20],
#  [2, 11, 31, 25, 21],
#  [44, 14, 15, 26, 21],
#  [41, 14, 16, 26, 21],
#  [7, 30, 17, 27, 24],
#  [6, 30, 16, 29, 24],
#  [35, 32, 15, 29, 23],
#  [38, 33, 19, 28, 20],
#  [35, 34, 18, 29, 21],
#  [36, 32, 16, 27, 20]]

# %%
df = pd.DataFrame(data, columns=['A','B','C','D','E'])
df
# Out:
#     A   B   C   D   E
# 0  47  10  31  25  20
# 1   2  11  31  25  21
# 2  44  14  15  26  21
# 3  41  14  16  26  21
# 4   7  30  17  27  24
# 5   6  30  16  29  24
# 6  35  32  15  29  23
# 7  38  33  19  28  20
# 8  35  34  18  29  21
# 9  36  32  16  27  20

# %%
import matplotlib.pyplot as plt
plt.hist(df)
# Out:
# (array([[ 2.,  1.,  0.,  0.,  0.,  0.,  0.,  3.,  2.,  2.],
#         [ 0.,  1.,  3.,  0.,  0.,  0.,  5.,  1.,  0.,  0.],
#         [ 0.,  0.,  2.,  6.,  0.,  0.,  2.,  0.,  0.,  0.],
#         [ 0.,  0.,  0.,  0.,  0.,  7.,  3.,  0.,  0.,  0.],
#         [ 0.,  0.,  0.,  0., 10.,  0.,  0.,  0.,  0.,  0.]]),
#  array([ 2. ,  6.5, 11. , 15.5, 20. , 24.5, 29. , 33.5, 38. , 42.5, 47. ]),
#  <a list of 5 BarContainer objects>)

# %%
plt.hist(df['A'])
# Out:
# (array([2., 1., 0., 0., 0., 0., 0., 3., 2., 2.]),
#  array([ 2. ,  6.5, 11. , 15.5, 20. , 24.5, 29. , 33.5, 38. , 42.5, 47. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(df['B'])
# Out:
# (array([2., 2., 0., 0., 0., 0., 0., 0., 2., 4.]),
#  array([10. , 12.4, 14.8, 17.2, 19.6, 22. , 24.4, 26.8, 29.2, 31.6, 34. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(df['C'])
# Out:
# (array([5., 2., 1., 0., 0., 0., 0., 0., 0., 2.]),
#  array([15. , 16.6, 18.2, 19.8, 21.4, 23. , 24.6, 26.2, 27.8, 29.4, 31. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(df['D'])
# Out:
# (array([2., 0., 2., 0., 0., 2., 0., 1., 0., 3.]),
#  array([25. , 25.4, 25.8, 26.2, 26.6, 27. , 27.4, 27.8, 28.2, 28.6, 29. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(df['E'])
# Out:
# (array([3., 0., 4., 0., 0., 0., 0., 1., 0., 2.]),
#  array([20. , 20.4, 20.8, 21.2, 21.6, 22. , 22.4, 22.8, 23.2, 23.6, 24. ]),
#  <BarContainer object of 10 artists>)

# %%
for col in df:
    #print(col)
    plt.hist(df[col])
    plt.show()

# %% [markdown]
# ## 첨도
#
# 양의 첨도 : 정규분포보다 값의 크기만큼 뽀족하다. 꼬리가 두껍다.
# 음의 첨도 : 정규분포보다 값의 크기만큼  평평하다. 꼬리가 얇다.

# %%
from scipy.stats import kurtosis
positive_kurtosis = [
    50, 50, 50, 50, 50,
    48, 52,
    35, 65
]
negative_kurtosis = [
    42, 44, 46, 48,
    52, 54, 56, 58
]
pos_kurtosis_value = kurtosis(positive_kurtosis )
neg_kurtosis_value = kurtosis(negative_kurtosis )

print(pos_kurtosis_value, neg_kurtosis_value )
# Out:
# 1.345540702885148 -1.4266666666666667

# %%
plt.hist(positive_kurtosis)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 plt.hist(positive_kurtosis)
#
# NameError: name 'plt' is not defined

# %%
plt.hist(negative_kurtosis)

# %% [markdown]
# ## 왜도 (Skewness)

# %%
from scipy.stats import skew #scipy 전체 가져오면 커서 skew만 가져옴

data = [10, 20, 30, 40, 100]  # 오른쪽으로 치우친 데이터
skew_value = skew(data)
print(skew_value)  # 양수 (오른쪽 꼬리)

# %% [markdown]
# # 그래프로 표현하기

# %%
# 막대도표
import matplotlib.pyplot as plt

# %%
teams = ['Strategy', 'Sales', 'Marketing', 'HR', 'IT']
counts = [12, 25, 18, 8, 30]

plt.bar(teams, counts) #x축, y축 순으로 데이터 지정

# %%
import numpy as np

# %%
# 그룹 막대 
teams = ['Strategy', 'Sales', 'Marketing', 'HR', 'IT']
score_2025 = [12, 25, 18, 8, 30]
score_2024 = [10, 20, 15, 5, 25]

x = np.arange(len(teams))
width = 0.35

plt.bar(x - width/2, score_2025, width, label='2025')
plt.bar(x + width/2, score_2024, width, label='2024')

plt.xticks(x, teams)
#plt.bar(teams, score_2025, label='2025')
#plt.bar(teams, score_2024, label= '2024')
plt.legend()

# %%
# 원도표
# 1.데이터 준비 (시장 점유율 상황)
labels = ['Company A', 'Company B', 'Company C', 'Others']
sizes = [45, 30, 15, 10]  # 합이 100이 되게 하는 것이 일반적
plt.pie(sizes, labels=labels,autopct='%1.1f%%')

# %%
plt.pie(sizes, labels=labels,autopct='%1.1f%%', wedgeprops={'width':0.6})

# %%
# !pip install yfinance

# %%
import matplotlib.pyplot as plt
import yfinance as yf
ticker = '005930.KS'
data = yf.download(ticker)
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
data.tail()
# Out:
# Price          Close      High       Low      Open    Volume
# Ticker     005930.KS 005930.KS 005930.KS 005930.KS 005930.KS
# Date
# 2026-01-06  138900.0  139300.0  132700.0  135300.0  45321341
# 2026-01-07  141000.0  144400.0  137600.0  143500.0  46317413
# 2026-01-08  138800.0  144500.0  138300.0  138300.0  41449329
# 2026-01-09  139000.0  140700.0  135200.0  136000.0  29520566
# 2026-01-12  140000.0  142000.0  139300.0  141000.0  11339369

# %%
data['Close']
# Out:
# Ticker      005930.KS
# Date
# 2025-12-12   108900.0
# 2025-12-15   104800.0
# 2025-12-16   102800.0
# 2025-12-17   107900.0
# 2025-12-18   107600.0
# 2025-12-19   106300.0
# 2025-12-22   110500.0
# 2025-12-23   111500.0
# 2025-12-24   111100.0
# 2025-12-26   117000.0
# 2025-12-29   119500.0
# 2025-12-30   119900.0
# 2026-01-02   128500.0
# 2026-01-05   138100.0
# 2026-01-06   138900.0
# 2026-01-07   141000.0
# 2026-01-08   138800.0
# 2026-01-09   139000.0
# 2026-01-12   140000.0

# %%
plt.figure(figsize=(12, 5)) #가로 12, 세로 5
plt.plot(data.index, data['Close'])

# %%
# 히스토그램

# %%
import numpy as np

# %%
#랜덤한 1000개의 데이터 생성
data = np.random.normal(loc=50000, scale=15000, size=1000)
len(data)
# Out:
# 1000

# %%
plt.hist(data)
# Out:
# (array([  5.,  29.,  83., 153., 249., 228., 152.,  66.,  25.,  10.]),
#  array([ 5304.37127852, 14389.9280636 , 23475.48484869, 32561.04163377,
#         41646.59841886, 50732.15520394, 59817.71198903, 68903.26877411,
#         77988.8255592 , 87074.38234428, 96159.93912937]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(data, bins=50)
# Out:
# (array([ 1.,  0.,  1.,  3.,  0.,  1.,  3.,  5.,  8., 12.,  7., 17., 13.,
#         22., 24., 28., 25., 28., 39., 33., 40., 58., 55., 54., 42., 39.,
#         52., 48., 44., 45., 47., 32., 25., 16., 32., 21.,  9., 14., 13.,
#          9.,  6.,  5.,  7.,  3.,  4.,  5.,  1.,  0.,  1.,  3.]),
#  array([ 5304.37127852,  7121.48263553,  8938.59399255, 10755.70534957,
#         12572.81670659, 14389.9280636 , 16207.03942062, 18024.15077764,
#         19841.26213465, 21658.37349167, 23475.48484869, 25292.5962057 ,
#         27109.70756272, 28926.81891974, 30743.93027676, 32561.04163377,
#         34378.15299079, 36195.26434781, 38012.37570482, 39829.48706184,
#         41646.59841886, 43463.70977587, 45280.82113289, 47097.93248991,
#         48915.04384693, 50732.15520394, 52549.26656096, 54366.37791798,
#         56183.48927499, 58000.60063201, 59817.71198903, 61634.82334604,
#         63451.93470306, 65269.04606008, 67086.1574171 , 68903.26877411,
#         70720.38013113, 72537.49148815, 74354.60284516, 76171.71420218,
#         77988.8255592 , 79805.93691621, 81623.04827323, 83440.15963025,
#         85257.27098727, 87074.38234428, 88891.4937013 , 90708.60505832,
#         92525.71641533, 94342.82777235, 96159.93912937]),
#  <BarContainer object of 50 artists>)

# %%
# 상자 도표
np.random.seed(42)

sales = np.random.normal(50000, 10000, 100)
marketing = np.random.normal(55000, 12000, 100)
it = np.random.normal(60000, 15000, 100)

# %%
sales
# Out:
# array([54967.14153011, 48617.35698829, 56476.88538101, 65230.29856408,
#        47658.46625277, 47658.63043051, 65792.12815507, 57674.34729153,
#        45305.25614065, 55425.60043586, 45365.82307188, 45342.7024643 ,
#        52419.62271566, 30867.19755342, 32750.82167487, 44377.12470759,
#        39871.68879666, 53142.47332595, 40919.75924479, 35876.96298665,
#        64656.48768922, 47742.23699513, 50675.28204688, 35752.51813787,
#        44556.17275475, 51109.2258971 , 38490.06422578, 53756.98018346,
#        43993.61310081, 47083.06250207, 43982.93387771, 68522.78184509,
#        49865.02775262, 39422.89071044, 58225.44912103, 37791.56350029,
#        52088.63595005, 30403.2987612 , 36718.13951102, 51968.61235869,
#        57384.66579995, 51713.6828119 , 48843.51717612, 46988.96304411,
#        35214.78009633, 42801.55791605, 45393.6122904 , 60571.22226219,
#        53436.18289568, 32369.59844637, 53240.83969395, 46149.17719584,
#        43230.77999694, 56116.76288841, 60309.99522496, 59312.80119116,
#        41607.82476777, 46907.87624149, 53312.63431404, 59755.45127122,
#        45208.25762155, 48143.41023336, 38936.65025994, 38037.93375919,
#        58125.25822394, 63562.40028571, 49279.8987842 , 60035.32897892,
#        53616.36025048, 43548.80245395, 53613.95605508, 65380.36566466,
#        49641.7396089 , 65646.43655814, 23802.5489591 , 58219.02504375,
#        50870.47068238, 47009.92649534, 50917.60776536, 30124.31085399,
#        47803.28112162, 53571.12571512, 64778.94044742, 44817.29781726,
#        41915.06397107, 44982.42956415, 59154.02117702, 53287.5110966 ,
#        44702.39796233, 55132.67433113, 50970.77549348, 59686.44990533,
#        42979.46906123, 46723.37853402, 46078.91846868, 35364.85051868,
#        52961.20277065, 52610.5527218 , 50051.13456642, 47654.12866625])

# %%
data = [sales, marketing, it] #numpy array의 리스트
labels = ['Sales', 'Marketing', 'IT']

# %%
plt.figure(figsize=(12, 5)) 
plt.boxplot(data, labels=labels)
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_16276\2254894871.py:2: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot(data, labels=labels)
# {'whiskers': [<matplotlib.lines.Line2D at 0x24bf8244ac0>,
#   <matplotlib.lines.Line2D at 0x24bf8245660>,
#   <matplotlib.lines.Line2D at 0x24bf8272e90>,
#   <matplotlib.lines.Line2D at 0x24bf82732b0>,
#   <matplotlib.lines.Line2D at 0x24bf81af520>,
#   <matplotlib.lines.Line2D at 0x24bf81af820>],
#  'caps': [<matplotlib.lines.Line2D at 0x24bf8245db0>,
#   <matplotlib.lines.Line2D at 0x24bf8246650>,
#   <matplotlib.lines.Line2D at 0x24bf8273a60>,
#   <matplotlib.lines.Line2D at 0x24bf81ae920>,
#   <matplotlib.lines.Line2D at 0x24bf81afb20>,
#   <matplotlib.lines.Line2D at 0x24bf81afe20>],
#  'boxes': [<matplotlib.lines.Line2D at 0x24bf81c2920>,
#   <matplotlib.lines.Line2D at 0x24bf82729e0>,
#   <matplotlib.lines.Line2D at 0x24bf81af220>],
#  'medians': [<matplotlib.lines.Line2D at 0x24bf8246da0>,
#   <matplotlib.lines.Line2D at 0x24bf81aec20>,
#   <matplotlib.lines.Line2D at 0x24bf81ae5f0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x24bf82723b0>,
#   <matplotlib.lines.Line2D at 0x24bf81aef20>,
#   <matplotlib.lines.Line2D at 0x24bf81ae140>],
#  'means': []}

# %%
#산점도
#데이터 준비
np.random.seed(42)
ad_spend = np.random.uniform(10, 100, 100)  # 광고비 (만원)
sales = 2.5 * ad_spend + np.random.normal(0, 15, 100)  # 매출액 (만원)
sales
# Out:
# array([110.57723276, 234.42560869, 191.07504856, 129.88462523,
#         56.80911578,  65.45545565,  60.23722341, 212.11557953,
#        148.1234736 , 176.78997435,  43.36254298, 248.16098338,
#        204.35319112,  80.4753114 ,  67.36678086,  80.79568958,
#         82.92370826, 138.15526492, 116.3060069 ,  68.57383232,
#        167.10870547,  60.30194773,  90.80924777, 103.91260774,
#        106.38518532, 195.35491147,  64.78588324, 128.6685896 ,
#        155.87399232,  41.51210571, 189.9903802 ,  65.98659502,
#         43.49986428, 237.38255715, 213.48563921, 206.49169519,
#         94.44155121,  83.92485734, 176.06701649, 128.55752123,
#         51.93792629, 118.88463421,  49.87975947, 240.87608596,
#         95.09097507, 160.42670216, 116.17690678, 120.98753882,
#        156.81266926,  99.44908688, 228.29849637, 190.91041931,
#        237.88203233, 218.78401903, 136.26754377, 233.4501475 ,
#         28.97625726,  76.2000305 ,  21.38477649, 121.4483405 ,
#        100.7035908 ,  81.22260941, 223.66869782,  86.80653376,
#         91.6221637 , 166.71376002,  32.5957021 , 208.26382855,
#         45.67213674, 258.77690381, 180.20081243,  49.90417915,
#         34.07159984, 212.9335915 , 187.80029512, 194.22333595,
#        188.33545718,  45.1438521 , 110.05087602,  40.35526712,
#        247.18488849, 172.34957235,  81.58250313,  49.14893294,
#         80.35079733, 109.97251651, 206.54032381, 156.14019628,
#        239.07350902, 137.44007207,  64.23960774, 213.93197186,
#        192.4958142 , 139.98132699, 185.12489905, 123.86685491,
#        141.45836097, 126.31400875,  34.86966551,  61.68331981])

# %%
plt.scatter(ad_spend, sales)
# 추세선 추가
z = np.polyfit(ad_spend, sales, 1)
p = np.poly1d(z)
plt.plot(ad_spend, p(ad_spend), "r--", alpha=0.8, label='Trend Line')
plt.legend()

# %%
url = "https://archive.ics.uci.edu/ml/machine-learning-databases/housing/housing.data"

# 이 데이터셋의 표준 컬럼명 (직접 지정 필요)
column_names = [
    'CRIM',    # 1인당 범죄율
    'ZN',      # 25,000평방피트 초과 주거 지역 비율
    'INDUS',   # 비소매 상업 지역 비율
    'CHAS',    # 찰스강 더미 변수 (1: 강 경계, 0: 아님)
    'NOX',     # 일산화질소 농도
    'RM',      # 주택당 평균 방 개수
    'AGE',     # 1940년 이전에 건축된 소유 주택 비율
    'DIS',     # 5개 보스턴 고용 센터까지의 가중 거리
    'RAD',     # 방사형 고속도로 접근성 지수
    'TAX',     # 10,000달러당 재산세율
    'PTRATIO', # 학생-교사 비율
    'B',       # 흑인 인구 비율 (현재는 윤리적 이슈로 사용 지양 권고되기도 함)
    'LSTAT',   # 하위 계층 비율 (%)
    'MEDV'     # 본인 소유 주택 가격(중앙값) - 타겟 변수
]

# %%
import pandas as pd

# %%
df = pd.read_csv(url, sep='\s+', header=None, names=column_names)

# %%
df.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296.0
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242.0
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242.0
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222.0
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222.0
#
#    PTRATIO       B  LSTAT  MEDV
# 0     15.3  396.90   4.98  24.0
# 1     17.8  396.90   9.14  21.6
# 2     17.8  392.83   4.03  34.7
# 3     18.7  394.63   2.94  33.4
# 4     18.7  396.90   5.33  36.2

# %%
df.tail()
# Out:
#         CRIM   ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 501  0.06263  0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273.0
# 502  0.04527  0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273.0
# 503  0.06076  0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273.0
# 504  0.10959  0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273.0
# 505  0.04741  0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273.0
#
#      PTRATIO       B  LSTAT  MEDV
# 501     21.0  391.99   9.67  22.4
# 502     21.0  396.90   9.08  20.6
# 503     21.0  396.90   5.64  23.9
# 504     21.0  393.45   6.48  22.0
# 505     21.0  396.90   7.88  11.9

# %%
room_cnt = df['RM']
house_price = df['MEDV']

# %%
# 추세선 추가
z = np.polyfit(room_cnt, house_price, 1)
p = np.poly1d(z)
plt.plot(room_cnt, p(room_cnt), "r--", alpha=0.6, label='Trend Line')
plt.scatter(room_cnt, house_price)

# %%
plt.scatter(df['RM'],df['MEDV'])

# %%
plt.scatter(df['LSTAT'],df['MEDV'])

# %%
plt.scatter(df['PTRATIO'],df['MEDV'])

# %%
plt.scatter(df['CRIM'],df['MEDV'])
