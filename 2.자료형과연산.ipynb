# %%
from IPython.display import HTML

HTML("""
<style>
/* Notebook 7 / JupyterLab */
.cm-editor, .cm-content {
    font-size: 30px !important;
    line-height: 1.4 !important;
}
</style>
""")
# Out:
# <style>
# /* Notebook 7 / JupyterLab */
# .cm-editor, .cm-content {
#     font-size: 30px !important;
#     line-height: 1.4 !important;
# }
# </style>

# %% [markdown]
# - 기본 자료형 : 정수형, 실수형 > 숫자형, 문자형, 부울 형 boolean
# - 복합 자료형 : list, tuple, dictionary, set

# %% [markdown]
# #  기본자료형

# %% [markdown]
# ## int 정수형

# %%
20, type(20)
# Out:
# (20, int)

# %%
a = 20 #10진수
a
# Out:
# 20

# %%
a = 0b0101  # 2**3*0+2**2*1+2**1*0+2**0*1
a
# Out:
# 5

# %%
a = 0o10 #0b1000, 0x16d
a
# Out:
# 8

# %% [markdown]
# ## float

# %%
b=3.14
type(b), b
# Out:
# (float, 3.14)

# %% [markdown]
# ## 지수의 표기
# 10e2

# %%
a = 10e2
a
# Out:
# 1000.0

# %%
a = 10e-2 # 10*10**-2
a
# Out:
# 0.1

# %%
3.1415e9 #3.1415 * 10**9
# Out:
# 3141500000.0

# %% [markdown]
# ## boolean 부울형
#
# True == 1 == 참, False==0==거짓 예약어

# %%
a = 10
a = 3.14
a = 3.14e5
a = True
b = False
a,b
# Out:
# (True, False)

# %%
type(a), type(b)
# Out:
# (bool, bool)

# %% [markdown]
# ### 논리연산, 비교연산

# %%
a == 0 #== 같다 비교연산자
# Out:
# False

# %%
a == 1
# Out:
# True

# %%
a == True
# Out:
# True

# %%
a == true
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 a == true
#
# NameError: name 'true' is not defined

# %%
b = 1
a and b, a, b
# Out:
# (1, True, 1)

# %% [markdown]
# ```
# and : a,b 모두 참(1)일때 1, 아니면 0
# or : a,b 둘중 1개만 참(1)일 때 1
# not : 반대 참(1)이면 거짓(0),
# ```

# %%
a = True
b = 1
a+b
# Out:
# 2

# %%
a and b
# Out:
# 1

# %%
if ( a and b ) : #조건식의 결과가 True(참)
    print('hello')

# %%
a = None
a and b

# %%
bool(0), bool(1), bool(2)
# Out:
# (False, True, True)

# %%
int('50')
# Out:
# 50

# %%
float('50')
# Out:
# 50.0

# %%
bool('50')
# Out:
# True

# %%
a=2
b=3

# %%
#사칙연산
a+b
a-b
a*b
a/b
a//b
a%b

# %%
#비교연산 == != > < >= <=
a == b
a != b
a > b
a >= b
# Out:
# False

# %%
#대입연산 = += -= 
a = 10
a += 2
a
# Out:
# 12

# %%
a = 10
a -= 2
print(a)
# Out:
# 8

# %% [markdown]
# # 문자열 str

# %%
first_name = 'ylee'
last_name = 'kim'
first_name + last_name
# Out:
# 'yleekim'

# %%
last_name == 'Kim'
# Out:
# False

# %%
last_name == 'Kim'.lower() #소문자, 대문자 Upper()
# Out:
# True

# %%
last_name.upper()
# Out:
# 'KIM'

# %%
last_name.capitalize()
# Out:
# 'Kim'

# %%
last_name.title()
# Out:
# 'Kim'

# %%
아기상어 = """아기 상어 뚜루루 뚜루
귀여운 뚜루루 뚜루
바닷속 뚜루루 뚜루
아기 상어!
엄마 상어 뚜루루 뚜루
어여쁜 뚜루루 뚜루
바닷속 뚜루루 뚜루
엄마 상어!
아빠 상어 뚜루루 뚜루
힘이 센 뚜루루 뚜루
바닷속 뚜루루 뚜루
아빠 상어!
할머니 상어 (뚜루루 뚜루)
자상한 (뚜루루 뚜루)
바닷속 뚜루루 뚜루
할머니 상어!
할아버지 상어 (뚜루루 뚜루)
멋있는 (뚜루루 뚜루)
바닷속 뚜루루 뚜루
할아버지 상어!
우리는 뚜루루 뚜루
바다의 뚜루루 뚜루
사냥꾼 뚜루루 뚜루
상어 가족!
상어다 뚜루루 뚜루
도망쳐 뚜루루 뚜루
도망쳐 뚜루루 뚜루
숨자! 으악!
살았다 뚜루루 뚜루
살았다 뚜루루 뚜루
오늘도 뚜루루 뚜루
살았다 휴!
신난다 (뚜루루 뚜루)
신난다 (뚜루루 뚜루)
춤을 춰 뚜루루 뚜루
노래 끝! 오예!"""

# %%
아기상어[0:10] #시작인덱스:끝인덱스
# Out:
# '아기 상어 뚜루루 '

# %%
아기상어.count("뚜루")
# Out:
# 54

# %%
#주민등록번호의 생년월일 부분만 출력해보세요
jumin = '001229-3123554'
jumin[0:6]
# Out:
# '001229'

# %%
jumin.split('-')[0]
# Out:
# '001229'

# %%
year = jumin[0:2]
month = jumin[2:4]
day = jumin[4:6]

# %%
year, month, day
# Out:
# ('0', '12', '29')

# %%
if year == '00' :
    print(month)
else :
    print(day)

# %%
jumin = '12345-67890ab'

# %%
jumin[1]
# Out:
# '2'

# %%
jumin[-2:]
# Out:
# 'ab'

# %%
jumin.split("-")[1][0]
# Out:
# '6'

# %%
jumin_new = jumin.replace('6','2')
jumin_new
# Out:
# '12345-27890ab'

# %%
print('**********************')
print('*'*20)
# Out:
# **********************
# ********************

# %% [markdown]
# ## 인덱싱과 슬라이싱

# %%
text = "Python"
print(text[0], text[-1]) #indexing

print(text[0:3])   # "Pyt"
print(text[2:])    # "thon"
print(text[:4])    # "Pyth"
print(text[-3:])   # "hon"
print(text[::2])   #??
# Out:
# P n
# Pyt
# thon
# Pyth
# hon
# Pto

# %%
dir(text)
# Out:
# ['__add__',
#  '__class__',
#  '__contains__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getnewargs__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mod__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rmod__',
#  '__rmul__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'capitalize',
#  'casefold',
#  'center',
#  'count',
#  'encode',
#  'endswith',
#  'expandtabs',
#  'find',
#  'format',
#  'format_map',
#  'index',
#  'isalnum',
#  'isalpha',
#  'isascii',
#  'isdecimal',
#  'isdigit',
#  'isidentifier',
#  'islower',
#  'isnumeric',
#  'isprintable',
#  'isspace',
#  'istitle',
#  'isupper',
#  'join',
#  'ljust',
#  'lower',
#  'lstrip',
#  'maketrans',
#  'partition',
#  'removeprefix',
# ...

# %%
'a'.encode('utf-8')
dec_value = 'a'.encode('utf-16')
dec_value
# Out:
# b'\xff\xfea\x00'

# %%
dec_value.decode('utf-16')
# Out:
# 'a'

# %%
# format()
#test_str = ' 99.99 dollars are worth us$ 100 입니다.'
test_str = ' {2:.4f} {1:s} are worth us$ {0:d} 입니다.' #템플릿
test_str.format(99,'dollars',100.0 )
# Out:
# ' 100.0000 dollars are worth us$ 99 입니다.'

# %%
num1 = 99
num2 = 100
str1 = 'dollars'
test_str = f' {num1:.4f} {str1:s} are worth us$ {num2:d} 입니다.'
test_str
# Out:
# ' 99.0000 dollars are worth us$ 100 입니다.'

# %%
len(test_str)
# Out:
# 39

# %%
email = 'aaa@gmail.com'
email_1 = 'aaa@gmail.com '
email_2 = ' aaa@gmail.com '
len(email), len(email_1)
# Out:
# (13, 14)

# %%
len(email_1.strip()), len(email_2.strip())
# Out:
# (13, 13)

# %%
아기상어.rfind('뚜루루') #index
# Out:
# 377

# %%
아기상어[377:380]
# Out:
# '뚜루루'

# %%
dir(email_1)
# Out:
# ['__add__',
#  '__class__',
#  '__contains__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getnewargs__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mod__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rmod__',
#  '__rmul__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'capitalize',
#  'casefold',
#  'center',
#  'count',
#  'encode',
#  'endswith',
#  'expandtabs',
#  'find',
#  'format',
#  'format_map',
#  'index',
#  'isalnum',
#  'isalpha',
#  'isascii',
#  'isdecimal',
#  'isdigit',
#  'isidentifier',
#  'islower',
#  'isnumeric',
#  'isprintable',
#  'isspace',
#  'istitle',
#  'isupper',
#  'join',
#  'ljust',
#  'lower',
#  'lstrip',
#  'maketrans',
#  'partition',
#  'removeprefix',
# ...

# %% [markdown]
# # 문자열
#
# 1. 인덱싱, 슬라이싱, 멤버십
# 2. 문자열은 immutable "불변", 대소문자 구분한다
# 3. 문자열은 코드를 지정 인코딩, 디코딩, 유니코드(이모지), 한글
# 4. 문자열 +, *
# 5. 공백처리, 형식처리 등을 해야 한다.

# %%
import re
text = "파이썬 문자열    처리"
#text.split(" ")
re.sub(r"\s+","    ", text)
# Out:
# '파이썬    문자열    처리'

# %%
tel_no = '010-123-1225'
re.sub(r'\D', "",tel_no)
# Out:
# '0101231225'

# %%
#생성자 creator, function 함수
int(1) #1
float(1) #1.0
str() #"", '', """ """, ''' '''

list() #[ ]
tuple() #( )
dict() # { }
set() # { }

# %%
# 사칙연산자, 비교 연산자, 대입연산자, 논리연산자, 기타...
+, -, *, / , %, //
>, <, ==, !=
=, +=, -=, *=, /=
and, or, not, &, |, !
in

# %%
# 타입별 메소드 제공
dir('a') 'a' + 'b'
# Out:
# ['__add__',
#  '__class__',
#  '__contains__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getnewargs__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mod__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rmod__',
#  '__rmul__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'capitalize',
#  'casefold',
#  'center',
#  'count',
#  'encode',
#  'endswith',
#  'expandtabs',
#  'find',
#  'format',
#  'format_map',
#  'index',
#  'isalnum',
#  'isalpha',
#  'isascii',
#  'isdecimal',
#  'isdigit',
#  'isidentifier',
#  'islower',
#  'isnumeric',
#  'isprintable',
#  'isspace',
#  'istitle',
#  'isupper',
#  'join',
#  'ljust',
#  'lower',
#  'lstrip',
#  'maketrans',
#  'partition',
#  'removeprefix',
# ...

# %%
dir([1,2])
# Out:
# ['__add__',
#  '__class__',
#  '__class_getitem__',
#  '__contains__',
#  '__delattr__',
#  '__delitem__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__reversed__',
#  '__rmul__',
#  '__setattr__',
#  '__setitem__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'append',
#  'clear',
#  'copy',
#  'count',
#  'extend',
#  'index',
#  'insert',
#  'pop',
#  'remove',
#  'reverse',
#  'sort']

# %%
list_obj.append()
list_obj.insert()  #데이터의 메소드
