# %% [markdown]
# # 헬로우

# %%
# 안녕하세요

# %%
"안녕하세요 "
print("반갑습니다.")
# Out:
# 반갑습니다.

# %%
#print("안녕하세요 ")
print("반갑습니다.")
# Out:
# 반갑습니다.

# %%
# 3*4
# 2*1
# 5*10

# %%
"반갑습니다."
'반갑습니다'
# Out:
# '반갑습니다'

# %%
"""안녕하세요

반갑습니다"""
# Out:
# '안녕하세요\n\n반갑습니다'

# %%
3*4
# Out:
# 12

# %%
2*1000
result
# Out:
# 7

# %%
def calculate_sum(a, b):
    result = a + b    # 들여쓰기된 코드 블록
    return result     # 같은 레벨의 들여쓰기

result = calculate_sum(3,4)

if result > 0:
     print(result)
     print("양수입니다")    # if문 내부의 들여쓰기된 코드
# Out:
# 7
# 양수입니다

# %%
print(result)
# Out:
# 7

# %% [markdown]
# # Jupyter Notebook

# %% [markdown]
# ## hello

# %% [markdown]
# ### 3 level

# %% [markdown]
# #### 4 level

# %% [markdown]
# ##### 5 level

# %% [markdown]
# * 하나
# * 둘
# * 셋

# %% [markdown]
# 1. one
# 2. two
# 3. three

# %% [markdown]
# * 바깥쪽 리스트
#     - 2번째 리스트
#         * 세번째 리스트

# %% [markdown]
# * 안녕
#   - 2

# %% [markdown]
# 1. 안녕
# 2. 반가워

# %% [markdown]
# | 비교 항목 | 파이썬 (Python) | 자바 (Java) |
# | :--- | :--- | :--- |
# | **문법 및 가독성** | 간결하고 직관적임 (동적 타이핑) | 엄격하고 코드가 김 (정적 타이핑) |
# | **실행 속도** | 인터프리터 방식으로 상대적으로 느림 | 컴파일 방식으로 상대적으로 빠름 |
# | **주요 활용** | AI, 데이터 분석, 자동화 스크립트 | 대규모 엔터프라이즈 시스템, 앱 개발 |

# %% [markdown]
# <div align="center">
# **개구리 점프**
# </div>
#
# | 번호 | 내용 | 주의사항 |
# |---|---|----|
# | 1 | 선택한다 |아무거나|

# %% [markdown]
# ![image.png](attachment:93f80566-d4d8-4b70-ba44-de64e6c630d6.png)

# %% [markdown]
# ![dog](https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcSGxwl4fhem6m2urbLPsROL7UHP2tjF4CowszALXe5IwDIMG7C2VdCqSyLCsNi4mrqWuKJgVE215SQCpX3TOTQSUgwhOnN_kBr2FB6omLvWww&s=10)
