# %% [markdown]
# # 프롬프트호출

# %%
from openai import OpenAI
import os

# %%
from dotenv import load_dotenv
load_dotenv()

# %%
import os
client = OpenAI(api_key=os.getenv("OPENAI_API_KEY"))

# %%
res = client.responses.create(
    model = 'gpt-4o-mini',
    input = [
        {"role" : "system", "content":"너는 마케팅 전문가야"},
        {"role" : "user", "content":"광고 문구를 작성"}
    ],
    temperature=0
)
res.output_text

# %%
response = client.responses.create(
    model = 'gpt-4o-mini',
    input = [
        msg("system", "You must only answer' questions in English." ),
        msg("user",''' 2025년 월드시리즈 우승팀은 어딘가요? ''')
    ],
    temperature=0
)
response.output_text

# %%
from openai import OpenAI
import os

# API 키 직접 넣거나 (연습용)
#client = OpenAI(api_key="")
#client

# %%
# 헬퍼 (지금까지 쓰던 그대로)
def msg(role, text):
    return {
        "role": role,
        "content": [
            {"type": "input_text", "text": text}
        ]
    }

# %%
from dotenv import load_dotenv
load_dotenv()

# %%
import os
client=OpenAI(api_key=os.getenv("OPENAI_API_KEY"))
client

# %%
res = client.responses.create(
    model = 'gpt-4o-mini',
    input = [
        msg("system", "너는 마케팅 전문가야" ),
        msg("user","광고 문구 작성")
        #{"role" : "system", "content":"너는 마케팅 전문가야"},
        #{"role" : "user", "content":"광고 문구 작성"}
    ],
    temperature=0
)
res.output_text

# %%
#res

# %%
res.output

# %%
res.output_text

# %%
def msg(role, text) :
    msg_src = {"role": role, "content": [{"type":"input_text", "text":text}] }
    return msg_src

# %%
res = client.responses.create(
    model = 'gpt-4o-mini',
    input = [
        msg("system","너는 마케팅 전문가야" ),
        msg("user","광고 문구를 작성")
        #{"role" : "system", "content":"너는 마케팅 전문가야"},
        #{"role" : "user", "content":"광고 문구를 작성"}
    ],
    temperature=0.6
)
res.output_text

# %%
# 프롬프트 호출 연습 1,2,3

# %% [markdown]
# # 역할 부여하기

# %%
response = client.responses.create(
    model="gpt-4o-mini",
    input=[
        msg("system", "너는 친절한 요약 전문가다. 1문장으로 요약하세요"),
        msg("user", '''이번 평가는 글로벌 빅테크 의존도를 낮추고 대한민국 고유의 ‘독자 AI(Sovereign AI)’를 확보하기 위한 국가 프로젝트다. LG AI연구원 컨소시엄은 △기술 성능(벤치마크) △전문가 평가 △사용자 평가를 종합한 결과 가장 높은 점수를 획득하며 1차 관문을 통과했다.

한컴은 이번 성과와 관련해 독자 AI 모델이 실제 서비스와 산업 현장으로 확산될 수 있도록 하는 문서 플랫폼 및 응용 서비스 역량이 컨소시엄 경쟁력 강화에 기여했다.

AI 기술을 연구 단계에 머무르지 않고, 공공·기업 환경에서 바로 활용 가능한 형태로 구현·검증해 온 경험이 이번 평가 과정에서 강점으로 작용했다는 설명이다.

한컴은 "실사용 환경에서의 효용성을 검증하는 ‘사용자 평가’에서 LG AI연구원 컨소시엄이 높은 점수를 받은 배경에도 이러한 요소가 영향을 미친 것"이라며 "한컴어시스턴트, 한컴피디아 등 자사 AI 서비스에 독자 AI 모델을 실제 적용·운영했다. 문서 작성, 요약, 지식 탐색 등 행정·업무 환경에서의 활용 가능성을 검증해 왔으며, 이러한 실증 사례가 ‘실제로 일하는 AI’의 가능성을 보여주는 데 일조했다"고 강조했다..''')
    ],
    temperature=0
)

response.output_text

# %%
res = client.responses.create(
    model = 'gpt-4o-mini',
    input = [
        {"role" : "system", "content":"너는 마케팅 전문가야"},
        {"role" : "user", "content":"광고 문구 작성"}
    ],
    temperature=0
)
res.output_text

# %%
response = client.responses.create(
    model="gpt-4o-mini",
    input=[
        msg("system", "너는 친절한 요약 전문가다. 반말로 1문장으로 요약하세요"),
        msg("user", '''이번 평가는 글로벌 빅테크 의존도를 낮추고 대한민국 고유의 ‘독자 AI(Sovereign AI)’를 확보하기 위한 국가 프로젝트다. LG AI연구원 컨소시엄은 △기술 성능(벤치마크) △전문가 평가 △사용자 평가를 종합한 결과 가장 높은 점수를 획득하며 1차 관문을 통과했다.

한컴은 이번 성과와 관련해 독자 AI 모델이 실제 서비스와 산업 현장으로 확산될 수 있도록 하는 문서 플랫폼 및 응용 서비스 역량이 컨소시엄 경쟁력 강화에 기여했다.

AI 기술을 연구 단계에 머무르지 않고, 공공·기업 환경에서 바로 활용 가능한 형태로 구현·검증해 온 경험이 이번 평가 과정에서 강점으로 작용했다는 설명이다.

한컴은 "실사용 환경에서의 효용성을 검증하는 ‘사용자 평가’에서 LG AI연구원 컨소시엄이 높은 점수를 받은 배경에도 이러한 요소가 영향을 미친 것"이라며 "한컴어시스턴트, 한컴피디아 등 자사 AI 서비스에 독자 AI 모델을 실제 적용·운영했다. 문서 작성, 요약, 지식 탐색 등 행정·업무 환경에서의 활용 가능성을 검증해 왔으며, 이러한 실증 사례가 ‘실제로 일하는 AI’의 가능성을 보여주는 데 일조했다"고 강조했다..''')
    ],
    temperature=0
)

response.output_text

# %%
response = client.responses.create(
    model="gpt-4o-mini",
    input=[
        msg("system", "You are a Korean-English translator. Translate the user's input into English."),
        msg("user", ''' 대한민국 고유의 ‘독자 AI(Sovereign AI)’를 확보하기 위한 국가 프로젝트다.  ''')
    ],
    temperature=0
)

response.output_text

# %%
response = client.responses.create(
    model="gpt-4o-mini",
    input=[
        msg("system", "You must only answer users' questions in English."),
        msg("user", ''' 2025년 메이저리그 월드시리즈 우승팀은 어딘가요? ''')
    ],
    temperature=0
)

response.output_text

# %% [markdown]
# # 이전 대화를 포함하여 대답하기

# %%
response = client.responses.create(
    model="gpt-4o-mini",
    input=[
        msg("user", "2002년 월드컵에서 가장 화제가 되었던 나라는 어디야?"),
        msg("user", "그나라가 화제가 되었던 이유는? ")
    ],
    temperature=0
)

response.output_text

# %%
response = client.responses.create(
    model="gpt-4o-mini",
    input=[
        msg("user","2002년 월드컵에서 가장 화제가 되었던 나라는 어디야?"),
        {
            "role": "assistant", #헬퍼는 그대로 두고, assistant만 명시적으로 처리
            "content": [
                {
                    "type": "output_text",
                    "text": "바로 예상을 뚫고 우승한 브라질입니다."
                }
            ]
        },
        msg("user","그 나라가 화제가 되었던 이유를 자세하게 설명해줘")
    ]
)

# %%
response.output_text

# %%
def msg_assist(role, text) :
    msg_src = {"role": role, "content": [{"type":"output_text", "text":text}] }
    return msg_src

# %%
response = client.responses.create(
    model="gpt-4o-mini",
    input=[
        msg("user","2002년 월드컵에서 가장 화제가 되었던 나라는 어디야?"),
        msg_assist("assistant","바로 예상을 뚫고 우승한 브라질입니다." ),
        msg("user","그 나라가 화제가 되었던 이유를 자세하게 설명해줘")
    ]
)
response.output_text

# %%
from dotenv import load_dotenv
import os

load_dotenv()

# 환경변수에서 API 키 읽기
client = OpenAI(
    api_key=os.getenv("OPENAI_API_KEY")
)

# %%
def msg(role, text):
    return {
        "role": role,
        "content": [{"type": "input_text", "text": text}]
    }

res = client.responses.create(
    model="gpt-4o-mini",
    input=[
        msg("system", "너는 마케팅 전문가다"),
        msg("user", "광고 문구 작성")
    ]
)

print(res.output_text)

# %%
- system
- user 
- assistant : 그 전에 기억하고 싶은 대화를 저장 -> 래그로 간다. 사람이 검수, 중간 산출물 삽입

# %%
response = client.responses.create(
    model = 'gpt-4o-mini',
    input = [
        msg("system", "You must only answer' questions in English." ),
        msg("user",''' 2025년 월드시리즈 우승팀은 어딘가요? ''')
    ],
    temperature=0
)
response.output_text

# %%
response = client.responses.create(
    model = 'gpt-4o-mini',
    input = [
        msg("user", "2002년 월드컵에서 가장 화제가 되었던 나라는 어디야?"),
        {
            "role": "assistant", #헬퍼는 그대로 두고 ou must only answer' questions in English." ),
        msg("user",''' 2025년 월드시리즈 우승팀은 어딘가요? ''')
    ],
    temperature=0
)
response.output_text
